# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_5_keras_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adapted from: https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_5_keras_transformers.ipynb

# %%
import pandas as pd
import numpy as np
import os

names = ['year', 'u' , 'x', 'obs_num']

path = r"C:\Users\sian_\OneDrive\Documents\Thesis\MILP_Formulation\Optimal_Control_Toy"
df = pd.read_csv("data_N200.csv",sep=',', header=0, names=names,index_col=False)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.bfill(inplace=True)
df.ffill(inplace=True) #for obs num


print("Starting file:")
print(df[0:10])

print("Ending file:")
print(df[-10:])

print(df.shape)
# Out:
# Starting file:
#        year         u         x  obs_num
# 0  0.000000  0.250000  1.000000      1.0
# 1  0.000111  0.250014  1.000118      1.0
# 2  0.000222  0.250028  1.000236      1.0
# 3  0.000333  0.250042  1.000354      1.0
# 4  0.000444  0.250056  1.000472      1.0
# 5  0.000556  0.250069  1.000590      1.0
# 6  0.000667  0.250083  1.000708      1.0
# 7  0.000778  0.250097  1.000826      1.0
# 8  0.000889  0.250111  1.000945      1.0
# 9  0.001000  0.250125  1.001063      1.0
# Ending file:
#            year         u         x  obs_num
# 26990  0.999000  1.998000  3.328337      3.0
# 26991  0.999111  1.998222  3.328892      3.0
# 26992  0.999222  1.998444  3.329446      3.0
# 26993  0.999333  1.998667  3.330001      3.0
# 26994  0.999444  1.998889  3.330556      3.0
# 26995  0.999556  1.999111  3.331112      3.0
# 26996  0.999667  1.999333  3.331667      3.0
# 26997  0.999778  1.999556  3.332222      3.0
# 26998  0.999889  1.999778  3.332778      3.0
# 26999  1.000000  2.000000  3.333333      3.0
# (27000, 4)

# %%
# # Find the last zero and move one beyond
# start_id = max(df[df['obs_num'] == 0].index.tolist())+1
# print(start_id)
# df = df[start_id:] # Trim the rows that have missing observations

# %% [markdown]
# Divide into training and test/validation sets.

# %%
df['u'] = df['u'].astype(float)
df12 = df[df['obs_num']<3.0]
df123 = df[df['obs_num']<4.0]

df_train = df123[df123['year']<0.7]
df_test = df123[df123['year']>=0.7]

spots_train_u = df_train['u'].tolist()
spots_train_x = df_train['x'].tolist()
spots_test_u = df_test['u'].tolist()
spots_test_x = df_test['x'].tolist()

print("Training set has {} observations.".format(len(spots_train_u)))
print("Test set has {} observations.".format(len(spots_test_u)))
# print(spots_train)
# Out:
# Training set has 18900 observations.
# Test set has 8100 observations.

# %%
df1 = df[df['obs_num']==1.0]
df2 = df[df['obs_num']==2.0]
df3 = df[df['obs_num']==3.0]

df_test1 = df1[df1['year']>=0.7]
df_test2 = df2[df2['year']>=0.7]
df_test3 = df3[df3['year']>=0.7]

spots_test1_u = df_test1['u'].tolist()
spots_test1_x = df_test1['x'].tolist()
spots_test2_x = df_test2['x'].tolist()
spots_test2_u = df_test2['u'].tolist()
spots_test3_x = df_test3['x'].tolist()
spots_test3_u = df_test3['u'].tolist()

print("Test set 1 has {} observations.".format(len(spots_test1_u)))
print("Test set 2 has {} observations.".format(len(spots_test2_u)))
print("Test set 3 has {} observations.".format(len(spots_test3_u)))
# Out:
# Test set 1 has 2700 observations.
# Test set 2 has 2700 observations.
# Test set 3 has 2700 observations.

# %% [markdown]
# The **to_sequences** function takes linear time series data into an **x** and **y** where **x** is all possible sequences of seq_size. After each **x** sequence, this function places the next value into the **y** variable. These **x** and **y** data can train a time-series neural network.

# %%
import numpy as np

def to_sequences(seq_size, obs_x, obs_u):

    x = []
    y = []
    for i in range((len(obs_x))-SEQUENCE_SIZE):
        window1 = obs_x[i:(i+SEQUENCE_SIZE)] #use values of x to predict [x(t+1), u(t+1)]
        window2 = obs_u[i:(i+SEQUENCE_SIZE)] #use values of x to predict [x(t+1), u(t+1)]
        after_window = [obs_x[i+SEQUENCE_SIZE],obs_u[i+SEQUENCE_SIZE]]
        window = [[x, u] for x,u in zip(window1, window2)]
        #print("{} - {}".format(window,after_window))
        x.append(window)
        y.append(after_window)

    return np.array(x),np.array(y)

SEQUENCE_SIZE = 10
x_train,y_train = to_sequences(SEQUENCE_SIZE,spots_train_x, spots_train_u )
x_test,y_test = to_sequences(SEQUENCE_SIZE,spots_test_x, spots_test_u)

print("Shape of x train set: {}".format(x_train.shape))
print("Shape of x test set: {}".format(x_test.shape))

print("Shape of y train set: {}".format(y_train.shape))
print("Shape of y test set: {}".format(y_test.shape))
# Out:
# Shape of x train set: (18890, 10, 2)
# Shape of x test set: (8090, 10, 2)
# Shape of y train set: (18890, 2)
# Shape of y test set: (8090, 2)

# %%
x_test1, y_test1 = to_sequences(SEQUENCE_SIZE,spots_test1_x, spots_test1_u)
print("Shape of y1 test set: {}".format(y_test1.shape))

x_test2, y_test2 = to_sequences(SEQUENCE_SIZE,spots_test2_x, spots_test2_u)
print("Shape of y2 test set: {}".format(y_test2.shape))

x_test3, y_test3 = to_sequences(SEQUENCE_SIZE,spots_test3_x, spots_test3_u)
print("Shape of y3 test set: {}".format(y_test3.shape))
# Out:
# Shape of y1 test set: (2690, 2)
# Shape of y2 test set: (2690, 2)
# Shape of y3 test set: (2690, 2)

# %% [markdown]
# We can view the results of the **to_sequences** encoding of the sunspot data.

# %%
# print('func 1',x_train[0])
# print('func 2',x_train[1])

# %%
#!pip install tensorflow

# %% [markdown]
# Next, we create the transformer_encoder; I obtained this function from a [Keras example](https://keras.io/examples/timeseries/timeseries_transformer_classification/). This layer includes residual connections, layer normalization, and dropout. This resulting layer can be stacked multiple times. We implement the projection layers with the Keras Conv1D.

# %%
from tensorflow import keras
from tensorflow.keras import layers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    ## NB dropout layer is only applied during training not inference (https://keras.io/api/layers/regularization_layers/dropout/)
    
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    # x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    # x = layers.Dropout(dropout)(x)
    # x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)

    x = layers.Dense(ff_dim, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(inputs.shape[-1], activation="relu")(x)
    
    #x = layers.Conv2D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    #x = layers.Dropout(dropout)(x)
    #x = layers.Conv2D(filters=inputs.shape[-1], kernel_size=1)(x)

    return x + res

# %% [markdown]
# The following function is provided to build the model, including the attention layer.

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0.25,
    mlp_dropout=0.25,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    print(x.shape, x)
    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    #x = layers.GlobalAveragePooling2D(data_format="channels_first")(x)
    print(x.shape, x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(2, activation="relu")(x)
    return keras.Model(inputs, outputs)

# %%
# model parameters:
model_params = {
    'input_shape': x_train.shape[1:],
    'head_size': 4,
    'num_heads': 12,
    'ff_dim': 32, #32
    'num_transformer_blocks': 1,
    'mlp_units': [128], #24
    'mlp_dropout': 0.1,
    'dropout': 0.1,
    'validation_split': 0.2,
    'epochs':1000,
    'batch_size': 64,
    'learning_rate': 1e-5
}
"""
model_params = {
    'input_shape': x_train.shape[1:],
    'head_size': 10,
    'num_heads': 4,
    'ff_dim': 4,
    'num_transformer_blocks': 1,
    'mlp_units': [128],
    'mlp_dropout': 0,
    'dropout': 0,
    'validation_split': 0.2,
    'epochs': 200,
    'batch_size': 64,
    'learning_rate': 1e-3
}
"""
# Out:
# "\nmodel_params = {\n    'input_shape': x_train.shape[1:],\n    'head_size': 10,\n    'num_heads': 4,\n    'ff_dim': 4,\n    'num_transformer_blocks': 1,\n    'mlp_units': [128],\n    'mlp_dropout': 0,\n    'dropout': 0,\n    'validation_split': 0.2,\n    'epochs': 200,\n    'batch_size': 64,\n    'learning_rate': 1e-3\n}\n"

# %% [markdown]
# We are now ready to build and train the model.

# %%
model = build_model(
    input_shape = model_params["input_shape"],
    head_size = model_params["head_size"],
    num_heads = model_params["num_heads"],
    ff_dim = model_params["ff_dim"],
    num_transformer_blocks = model_params['num_transformer_blocks'],
    mlp_units = model_params["mlp_units"],
    mlp_dropout = model_params["mlp_dropout"],
    dropout = model_params["dropout"],
)

model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=model_params['learning_rate'])
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=2, \
    restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split = model_params["validation_split"],
    epochs = model_params["epochs"],
    batch_size = model_params["batch_size"],
    callbacks=callbacks,
    shuffle=True,
)

model.evaluate(x_test, y_test, verbose=1)
# Out:
# (None, 10, 2) <KerasTensor shape=(None, 10, 2), dtype=float32, sparse=False, name=keras_tensor_65>
# (None, 2) <KerasTensor shape=(None, 2), dtype=float32, sparse=False, name=keras_tensor_66>
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 10, 2)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 2)     │          4 │ input_layer_4[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 2)     │        530 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 10, 2)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 10, 2)     │          0 │ dropout_17[0][0], │
# │                     │                   │            │ input_layer_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 2)     │          4 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 10, 32)    │         96 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 10, 32)    │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 10, 2)     │         66 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 10, 2)     │          0 │ dense_17[0][0],   │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2)         │          0 │ add_9[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 128)       │        384 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 128)       │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 2)         │        258 │ dropout_19[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,342 (5.24 KB)
#  Trainable params: 1,342 (5.24 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 0.9707 - val_loss: 1.6521
# Epoch 2/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - loss: 0.8830 - val_loss: 1.3910
# Epoch 3/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.7537 - val_loss: 1.1501
# Epoch 4/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 0.6192 - val_loss: 0.9291
# Epoch 5/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.4941 - val_loss: 0.7303
# Epoch 6/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.3798 - val_loss: 0.5587
# Epoch 7/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 0.2800 - val_loss: 0.4192
# Epoch 8/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.1967 - val_loss: 0.3139
# Epoch 9/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.1322 - val_loss: 0.2410
# Epoch 10/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - loss: 0.0857 - val_loss: 0.1950
# Epoch 11/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 0.0568 - val_loss: 0.1690
# Epoch 12/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0389 - val_loss: 0.1561
# Epoch 13/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0312 - val_loss: 0.1481
# Epoch 14/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 0.0268 - val_loss: 0.1444
# Epoch 15/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 0.0263 - val_loss: 0.1418
# Epoch 16/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - loss: 0.0249 - val_loss: 0.1413
# Epoch 17/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0253 - val_loss: 0.1409
# Epoch 18/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0246 - val_loss: 0.1407
# Epoch 19/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0246 - val_loss: 0.1387
# Epoch 20/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0237 - val_loss: 0.1386
# Epoch 21/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0235 - val_loss: 0.1372
# Epoch 22/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 0.0225 - val_loss: 0.1364
# Epoch 23/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 0.0227 - val_loss: 0.1366
# Epoch 24/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - loss: 0.0220 - val_loss: 0.1355
# Epoch 25/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - loss: 0.0220 - val_loss: 0.1363
# Epoch 26/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0211 - val_loss: 0.1354
# Epoch 27/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0203 - val_loss: 0.1368
# Epoch 28/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0201 - val_loss: 0.1350
# Epoch 29/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0193 - val_loss: 0.1338
# Epoch 30/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0187 - val_loss: 0.1307
# Epoch 31/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0182 - val_loss: 0.1272
# Epoch 32/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0176 - val_loss: 0.1260
# Epoch 33/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0174 - val_loss: 0.1245
# Epoch 34/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0166 - val_loss: 0.1213
# Epoch 35/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0160 - val_loss: 0.1192
# Epoch 36/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0158 - val_loss: 0.1178
# Epoch 37/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0149 - val_loss: 0.1157
# Epoch 38/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0145 - val_loss: 0.1116
# Epoch 39/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0137 - val_loss: 0.1082
# Epoch 40/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0131 - val_loss: 0.1050
# Epoch 41/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0125 - val_loss: 0.1009
# Epoch 42/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0124 - val_loss: 0.0971
# Epoch 43/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0116 - val_loss: 0.0943
# Epoch 44/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0114 - val_loss: 0.0909
# Epoch 45/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0108 - val_loss: 0.0875
# Epoch 46/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0107 - val_loss: 0.0828
# Epoch 47/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0099 - val_loss: 0.0801
# Epoch 48/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0097 - val_loss: 0.0766
# Epoch 49/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0092 - val_loss: 0.0731
# Epoch 50/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0092 - val_loss: 0.0695
# Epoch 51/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0088 - val_loss: 0.0662
# Epoch 52/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0084 - val_loss: 0.0638
# Epoch 53/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0080 - val_loss: 0.0591
# Epoch 54/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0077 - val_loss: 0.0548
# Epoch 55/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0077 - val_loss: 0.0511
# Epoch 56/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0074 - val_loss: 0.0488
# Epoch 57/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0072 - val_loss: 0.0436
# Epoch 58/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0066 - val_loss: 0.0398
# Epoch 59/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0064 - val_loss: 0.0374
# Epoch 60/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0064 - val_loss: 0.0339
# Epoch 61/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0064 - val_loss: 0.0320
# Epoch 62/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0063 - val_loss: 0.0291
# Epoch 63/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0058 - val_loss: 0.0271
# Epoch 64/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0059 - val_loss: 0.0253
# Epoch 65/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0057 - val_loss: 0.0236
# Epoch 66/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0057 - val_loss: 0.0212
# Epoch 67/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0055 - val_loss: 0.0198
# Epoch 68/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0055 - val_loss: 0.0188
# Epoch 69/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0055 - val_loss: 0.0176
# Epoch 70/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0055 - val_loss: 0.0163
# Epoch 71/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0052 - val_loss: 0.0154
# Epoch 72/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0051 - val_loss: 0.0143
# Epoch 73/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0051 - val_loss: 0.0136
# Epoch 74/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0050 - val_loss: 0.0130
# Epoch 75/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0049 - val_loss: 0.0121
# Epoch 76/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0050 - val_loss: 0.0113
# Epoch 77/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 0.0050 - val_loss: 0.0110
# Epoch 78/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0048 - val_loss: 0.0104
# Epoch 79/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0049 - val_loss: 0.0097
# Epoch 80/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0045 - val_loss: 0.0095
# Epoch 81/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0045 - val_loss: 0.0093
# Epoch 82/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0046 - val_loss: 0.0088
# Epoch 83/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0044 - val_loss: 0.0083
# Epoch 84/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0045 - val_loss: 0.0082
# Epoch 85/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0043 - val_loss: 0.0078
# Epoch 86/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0044 - val_loss: 0.0076
# Epoch 87/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0043 - val_loss: 0.0075
# Epoch 88/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0044 - val_loss: 0.0069
# Epoch 89/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0044 - val_loss: 0.0071
# Epoch 90/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0042 - val_loss: 0.0065
# Epoch 91/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 92/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 93/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 94/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0041 - val_loss: 0.0062
# Epoch 95/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0041 - val_loss: 0.0060
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0020
# 0.004331548698246479

# %% [markdown]
# Finally, we evaluate the model with RMSE.

# %%
name = 'transformer_small_relu_TOY_2.keras'
model.save(name , overwrite=True)

# %%
from sklearn import metrics

#score_x = np.sqrt(metrics.mean_squared_error(pred[:,0],y_test[:,0]))
#print("X Score (RMSE): {}".format(score_x))

#score_u = np.sqrt(metrics.mean_squared_error(pred[:,1],y_test[:,1]))
#print("U Score (RMSE): {}".format(score_u))

# %%
preds_x = []
rmse_x = []
preds_u = []
rmse_u = []

for x,y in [[x_test1, y_test1],[x_test2, y_test2],[x_test3, y_test3]]:
    pred = model.predict(x)

    score_x = np.sqrt(metrics.mean_squared_error(pred[:,0],y[:,0]))
    print("X Score (RMSE): {}".format(score_x))
    preds_x.append(pred[:,0])
    rmse_x.append(score_x)

    score_u = np.sqrt(metrics.mean_squared_error(pred[:,1],y[:,1]))
    print("U Score (RMSE): {}".format(score_u))
    preds_u.append(pred[:,1])
    rmse_u.append(score_u)

print('Prediction shape: ', len(preds_x))
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# X Score (RMSE): 0.055719370763198564
# U Score (RMSE): 0.028738273007180185
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# X Score (RMSE): 0.02350567818449558
# U Score (RMSE): 0.012211002904632803
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# X Score (RMSE): 0.013473105272430534
# U Score (RMSE): 0.14409140805143578
# Prediction shape:  3

# %%
import csv
# New filename for clarity
new_filename = "results_small_relu_2.csv"

# Create and write to the new CSV file with model parameters and results
with open(new_filename, 'a', newline='') as file:
    writer = csv.writer(file)
    # Writing headers for model parameters
    headers = list(model_params.keys())
    headers.append('rmse_x_1')
    headers.append('rmse_x_2')
    headers.append('rmse_x_3')
    headers.append('rmse_u_1')
    headers.append('rmse_u_2')
    headers.append('rmse_u_3')
    headers.append(name)
    writer.writerow(headers)
    
    # Writing values
    values = list(model_params.values())
    values.append(rmse_x[0])  # Adding first RMSE
    values.append(rmse_x[1])  # Adding second RMSE
    values.append(rmse_x[2])  
    values.append(rmse_u[0])  # Adding first RMSE
    values.append(rmse_u[1])  # Adding second RMSE
    values.append(rmse_u[2])
    values.append('')
    writer.writerow(values)

# %%
import matplotlib.pyplot as plt
func = 0
plt.figure(figsize=(6, 4))
plt.plot(y_test1[:,0], 's-',color='C1', label=f'x actual {func+1}')
plt.plot(preds_x[func], '-',color='C2', label=f'x pred {func+1}')
plt.plot(y_test1[:,1], 's-',color='C0', label=f'u actual {func+1}')
plt.plot(preds_u[func], '-',color='C3', label=f'u pred {func+1}')
plt.legend()

# %%
import matplotlib.pyplot as plt
func = 1
plt.figure(figsize=(6, 4))
plt.plot(y_test2[:,0], 's-',color='C1', label=f'x actual {func+1}')
plt.plot(preds_x[func], '-',color='C2', label=f'x pred {func+1}')
plt.plot(y_test2[:,1], 's-',color='C0', label=f'u actual {func+1}')
plt.plot(preds_u[func], '-',color='C3', label=f'u pred {func+1}')
plt.legend()

# %%
import matplotlib.pyplot as plt
func = 2
plt.figure(figsize=(6, 4))
plt.plot(y_test3[:,0], 's-',color='C1', label=f'x actual {func+1}')
plt.plot(preds_x[func], '-',color='C2', label=f'x pred {func+1}')
plt.plot(y_test3[:,1], 's-',color='C0', label=f'u actual {func+1}')
plt.plot(preds_u[func], '-',color='C3', label=f'u pred {func+1}')
plt.legend()
