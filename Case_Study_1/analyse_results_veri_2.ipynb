# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import gurobi_logtools as glt

# %%
name = "Verification_16"
PATH = f".\Experiments\{name}\Logs"

# %%
result = glt.parse(PATH+"\*.log")
summary = result.summary()

# %%
nl = result.progress("nodelog")
print(nl[~nl['Incumbent'].isna()])
nl.head()
# Out:
#        CurrentNode  RemainingNodes       Obj  Depth  IntInf  Incumbent  \
# 61            1905          1257.0       NaN    NaN     NaN  16.244195
# 62            1983          1294.0  15.69670  149.0  1274.0  16.244190
# 63            3012          1485.0  16.01246  151.0  1306.0  16.244190
# 64            4062          1504.0  15.93579  161.0  1301.0  16.244190
# 65            5179          1493.0  15.92330  158.0  1268.0  16.244190
# ...            ...             ...       ...    ...     ...        ...
# 29408     32883734       7822345.0       NaN  156.0     NaN  11.880840
# 29409     32887488       7823226.0  11.80859  143.0   585.0  11.880840
# 29410     32891384       7824007.0       NaN  148.0     NaN  11.880840
# 29411     32896684       7825182.0  11.80020  156.0   588.0  11.880840
# 29412     32896995             NaN       NaN    NaN     NaN  11.880840
#
#           BestBd       Gap  ItPerNode      Time NewSolution      Pruned  \
# 61     10.377930  0.361000      821.0    432.00           H         NaN
# 62     15.594460  0.040000      826.0    435.00         NaN         NaN
# 63     15.735400  0.031300      582.0    440.00         NaN         NaN
# 64     15.771890  0.029100      461.0    445.00         NaN         NaN
# 65     15.792530  0.027800      385.0    450.00         NaN         NaN
# ...          ...       ...        ...       ...         ...         ...
# 29408  11.705990  0.014700      100.0  43187.00         NaN  infeasible
# 29409  11.706000  0.014700      100.0  43191.00         NaN         NaN
# 29410  11.706000  0.014700      100.0  43195.00         NaN      cutoff
# 29411  11.706000  0.014700      100.0  43200.00         NaN         NaN
# 29412  11.706003  0.014716        NaN  43200.06         NaN         NaN
#
#                                              LogFilePath  LogNumber  Seed  \
# 61     .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0
# 62     .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0
# 63     .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0
# 64     .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0
# 65     .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0
# ...                                                  ...        ...   ...
# 29408  .\Experiments\Verification_16\Logs\vit_6_1_6_1...          1     0
# 29409  .\Experiments\Verification_16\Logs\vit_6_1_6_1...          1     0
# 29410  .\Experiments\Verification_16\Logs\vit_6_1_6_1...          1     0
# 29411  .\Experiments\Verification_16\Logs\vit_6_1_6_1...          1     0
# 29412  .\Experiments\Verification_16\Logs\vit_6_1_6_1...          1     0
#
#       Version
# 61     11.0.2
# 62     11.0.2
# 63     11.0.2
# 64     11.0.2
# 65     11.0.2
# ...       ...
# 29408  11.0.2
# 29409  11.0.2
# 29410  11.0.2
# 29411  11.0.2
# 29412  11.0.2
#
# [24522 rows x 16 columns]
# c:\Users\sian_\OneDrive\Documents\Thesis\Transformer_Formulation\pyomo_env\lib\site-packages\gurobi_logtools\api.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   left=pd.concat(progress),
#    CurrentNode  RemainingNodes       Obj  Depth  IntInf  Incumbent    BestBd  \
# 0            0             0.0 -70.19216    0.0  1347.0        NaN -70.19216
# 1            0             0.0 -70.19164    0.0  1366.0        NaN -70.19164
# 2            0             0.0 -70.19164    0.0  1364.0        NaN -70.19164
# 3            0             0.0 -70.17021    0.0  1362.0        NaN -70.17021
# 4            0             0.0 -70.17020    0.0  1364.0        NaN -70.17020
#
#    Gap  ItPerNode  Time NewSolution Pruned  \
# 0  NaN        NaN   0.0         NaN    NaN
# 1  NaN        NaN   1.0         NaN    NaN
# 2  NaN        NaN   1.0         NaN    NaN
# 3  NaN        NaN   2.0         NaN    NaN
# 4  NaN        NaN   2.0         NaN    NaN
#
#                                          LogFilePath  LogNumber  Seed Version
# 0  .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0  11.0.2
# 1  .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0  11.0.2
# 2  .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0  11.0.2
# 3  .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0  11.0.2
# 4  .\Experiments\Verification_16\Logs\vit_18_1_6_...          1     0  11.0.2

# %%
regex_pattern = r'vit_(\d+)_(\d+)_(\d+)_(\d+)_i(\d+)_r(\d+)_c(\d+)\.log'
nl[['Embed_Dim', 'Enc_Layers', 'Heads', 'Mlp_Dim', 'I', 'Repetition', 'Config']] = nl['LogFilePath'].str.extract(regex_pattern)
nl.head()
# Out:
#    CurrentNode  RemainingNodes       Obj  Depth  IntInf  Incumbent    BestBd  \
# 0            0             0.0 -70.19216    0.0  1347.0        NaN -70.19216
# 1            0             0.0 -70.19164    0.0  1366.0        NaN -70.19164
# 2            0             0.0 -70.19164    0.0  1364.0        NaN -70.19164
# 3            0             0.0 -70.17021    0.0  1362.0        NaN -70.17021
# 4            0             0.0 -70.17020    0.0  1364.0        NaN -70.17020
#
#    Gap  ItPerNode  Time  ... LogNumber Seed Version  Embed_Dim  Enc_Layers  \
# 0  NaN        NaN   0.0  ...         1    0  11.0.2         18           1
# 1  NaN        NaN   1.0  ...         1    0  11.0.2         18           1
# 2  NaN        NaN   1.0  ...         1    0  11.0.2         18           1
# 3  NaN        NaN   2.0  ...         1    0  11.0.2         18           1
# 4  NaN        NaN   2.0  ...         1    0  11.0.2         18           1
#
#   Heads Mlp_Dim  I Repetition Config
# 0     6      12  4          2      2
# 1     6      12  4          2      2
# 2     6      12  4          2      2
# 3     6      12  4          2      2
# 4     6      12  4          2      2
#
# [5 rows x 23 columns]

# %%
nl
# Out:
#        CurrentNode  RemainingNodes       Obj  Depth  IntInf  Incumbent  \
# 0                0             0.0 -70.19216    0.0  1347.0        NaN
# 1                0             0.0 -70.19164    0.0  1366.0        NaN
# 2                0             0.0 -70.19164    0.0  1364.0        NaN
# 3                0             0.0 -70.17021    0.0  1362.0        NaN
# 4                0             0.0 -70.17020    0.0  1364.0        NaN
# ...            ...             ...       ...    ...     ...        ...
# 30686       941609        570249.0 -41.00561   82.0  1057.0        NaN
# 30687       944193        571342.0       NaN  184.0     NaN        NaN
# 30688       946226        572888.0 -41.00561   75.0  1051.0        NaN
# 30689       948544        572959.0 -41.00561  135.0  1024.0        NaN
# 30690       948707             NaN       NaN    NaN     NaN        NaN
#
#           BestBd  Gap  ItPerNode      Time  ... LogNumber Seed Version  \
# 0     -70.192160  NaN        NaN      0.00  ...         1    0  11.0.2
# 1     -70.191640  NaN        NaN      1.00  ...         1    0  11.0.2
# 2     -70.191640  NaN        NaN      1.00  ...         1    0  11.0.2
# 3     -70.170210  NaN        NaN      2.00  ...         1    0  11.0.2
# 4     -70.170200  NaN        NaN      2.00  ...         1    0  11.0.2
# ...          ...  ...        ...       ...  ...       ...  ...     ...
# 30686 -41.005620  NaN     1192.0  42936.00  ...         1    0  11.0.2
# 30687 -41.005620  NaN     1192.0  43067.00  ...         1    0  11.0.2
# 30688 -41.005620  NaN     1193.0  43190.00  ...         1    0  11.0.2
# 30689 -41.005620  NaN     1194.0  43200.00  ...         1    0  11.0.2
# 30690 -41.005616  NaN        NaN  43200.01  ...         1    0  11.0.2
#
#        Embed_Dim  Enc_Layers Heads Mlp_Dim  I Repetition Config
# 0             18           1     6      12  4          2      2
# 1             18           1     6      12  4          2      2
# 2             18           1     6      12  4          2      2
# 3             18           1     6      12  4          2      2
# 4             18           1     6      12  4          2      2
# ...          ...         ...   ...     ... ..        ...    ...
# 30686          6           2     6      12  4          2      3
# 30687          6           2     6      12  4          2      3
# 30688          6           2     6      12  4          2      3
# 30689          6           2     6      12  4          2      3
# 30690          6           2     6      12  4          2      3
#
# [30691 rows x 23 columns]

# %%
# select only enc layers = 1 --> compare embed dim = 6, 18
Vary = 'Enc_Layers'
grouped_nl = nl.groupby([Vary , 'Config', 'Time']).agg({
    'Incumbent': ['mean', 'std'],
    'BestBd': ['mean', 'std']
}).reset_index()

configs = grouped_nl[[Vary , 'Config']].drop_duplicates().values
grouped_nl.head()
# Out:
#   Enc_Layers Config Time Incumbent         BestBd
#                               mean std       mean       std
# 0          1      2  0.0       NaN NaN -52.895489  6.988911
# 1          1      2  1.0       NaN NaN -70.191640  0.000000
# 2          1      2  2.0       NaN NaN -70.160702  0.009439
# 3          1      2  3.0       NaN NaN -70.116119  0.012579
# 4          1      2  4.0       NaN NaN -70.105640       NaN

# %%
configs
# Out:
# array([['1', '2'],
#        ['1', '3'],
#        ['2', '2'],
#        ['2', '3']], dtype=object)

# %%
grouped_nl.columns = [Vary , 'Config', 'Time', 'Incumbent_mean', 'Incumbent_std', 'BestBd_mean', 'BestBd_std']
grouped_nl.head()
# Out:
#   Enc_Layers Config  Time  Incumbent_mean  Incumbent_std  BestBd_mean  \
# 0          1      2   0.0             NaN            NaN   -52.895489
# 1          1      2   1.0             NaN            NaN   -70.191640
# 2          1      2   2.0             NaN            NaN   -70.160702
# 3          1      2   3.0             NaN            NaN   -70.116119
# 4          1      2   4.0             NaN            NaN   -70.105640
#
#    BestBd_std
# 0    6.988911
# 1    0.000000
# 2    0.009439
# 3    0.012579
# 4         NaN

# %%
# combinations = {
#     #'All': {'LN_I': 1, 'MHA_I': 1, 'MHA_D': 1, 'MHA_MC': 1},
#     #'No_MC': {'LN_I': 1, 'MHA_I': 1, 'MHA_D': 1, 'MHA_MC': 0},
#     # 'I_only': {'LN_I': 1, 'MHA_I': 1, 'MHA_D': 0, 'MHA_MC': 0},
#     # # 'LN_only': {'LN_I': 1, 'MHA_I': 0, 'MHA_D': 0, 'MHA_MC': 0},
#     # # 'Prop_MC': {'LN_I': 1, 'MHA_I': 0, 'MHA_D': 1, 'MHA_MC': 1},
#     # 'LN_prop': {'LN_I': 1, 'MHA_I': 0, 'MHA_D': 1, 'MHA_MC': 0},
#     # 'None': {'LN_I': 0, 'MHA_I': 0, 'MHA_D': 0, 'MHA_MC': 0},
# }
conf = ['No_MC','I_only', 'LN_prop']
combinations = {}
for i in configs:
    combinations[f'{Vary }_{i[0]}_{conf[int(i[-1])-1]}'] = i[0]+i[-1]
    
print(combinations)
# Out:
# {'Enc_Layers_1_I_only': '12', 'Enc_Layers_1_LN_prop': '13', 'Enc_Layers_2_I_only': '22', 'Enc_Layers_2_LN_prop': '23'}

# %%
import matplotlib.pyplot as plt

# Initialize the figure size
colors = plt.get_cmap('tab10', len(grouped_nl['Config'].unique()))
config_names = list(combinations.keys())

# Find the global min and max values for both the x and y axes across all configurations
x_min = grouped_nl['Time'].min() #10#
x_max = grouped_nl['Time'].max()

y_min = min(grouped_nl['Incumbent_mean'].min(), grouped_nl['BestBd_mean'].min()) #1e-4 #
y_max = max(grouped_nl['Incumbent_mean'].max(), grouped_nl['BestBd_mean'].max())

# Plot each configuration using the same x and y axis limits
for i, config in enumerate(configs):
    plt.figure(i, figsize=(10, 6))
    config_data = grouped_nl[(grouped_nl[Vary] == config[0]) & (grouped_nl['Config'] == config[-1])]
    color = colors(i)

    # Plot Incumbent mean
    plt.plot(config_data['Time'], config_data['Incumbent_mean'], 'o-',linestyle='-', label=f'{config_names[i]} - Incumbent', color='k')
    #Add shaded area for Incumbent std
    plt.fill_between(config_data['Time'], 
                     config_data['Incumbent_mean'] - config_data['Incumbent_std'], 
                     config_data['Incumbent_mean'] + config_data['Incumbent_std'], 
                     color="black", alpha=0.5)

    # Plot BestBd mean
    plt.plot(config_data['Time'], config_data['BestBd_mean'], linestyle='--', label=f'{config_names[i]} - BestBd', color=color)
    # Add shaded area for BestBd std
    # plt.fill_between(config_data['Time'], 
    #                  config_data['BestBd_mean'] - config_data['BestBd_std'], 
    #                  config_data['BestBd_mean'] + config_data['BestBd_std'], 
    #                  color="black", alpha=0.5)
    # Set to log scale
    plt.yscale('log')
    plt.xscale('log')

    # # Set the same x and y limits for all plots
    # plt.xlim(x_min, x_max)
    # plt.ylim(y_min, y_max)

    # Add labels
    plt.grid(True)
    plt.xlabel('Time (seconds)')
    plt.ylabel('Objective Value')
    plt.legend()
    

    # PATH = r"C:\Users\sian_\OneDrive\Documents\Thesis"
    # plt.savefig(PATH+f'\images\{config_names[i]}_time_conv.png')  
    # #plt.show()
# Out:
# C:\Users\sian_\AppData\Local\Temp\ipykernel_27320\1229474395.py:21: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(config_data['Time'], config_data['Incumbent_mean'], 'o-',linestyle='-', label=f'{config_names[i]} - Incumbent', color='k')
# C:\Users\sian_\AppData\Local\Temp\ipykernel_27320\1229474395.py:36: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %%
grouped_nl2 = nl.groupby(['Config', 'CurrentNode']).agg({
    'Incumbent': ['mean', 'std'],
    'BestBd': ['mean', 'std']
}).reset_index()

configs = grouped_nl2['Config'].unique()
grouped_nl2.columns = ['Config', 'Node', 'Incumbent_mean', 'Incumbent_std', 'BestBd_mean', 'BestBd_std']
grouped_nl2.head()
# Out:
#   Config  Node  Incumbent_mean  Incumbent_std  BestBd_mean  BestBd_std
# 0      2     0             NaN            NaN    -60.14027   12.517806
# 1      2     1             NaN            NaN    -55.52140   20.528427
# 2      2     3             NaN            NaN    -41.00561         NaN
# 3      2    19             NaN            NaN    -50.42436         NaN
# 4      2    35             NaN            NaN    -70.01237         NaN

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the number of subplots based on the number of configurations
num_configs = len(configs)
fig, axes = plt.subplots(nrows=2, ncols=(num_configs + 1) // 2, figsize=(15, 10))  # Adjust subplot grid

# Set the color map for the plots
colors = plt.get_cmap('tab10', num_configs)

# Find the global min and max values for the x and y axes across all configurations
x_min = grouped_nl2['Node'].min()
x_max = 1.25e7
y_min = 1e-4
y_max = max(grouped_nl2['Incumbent_mean'].max(), grouped_nl2['BestBd_mean'].max())

# Flatten axes array for easy iteration
axes = axes.flatten()

# Plot each configuration in a separate subplot
for i, config in enumerate(configs):
    ax = axes[i]
    config_data = grouped_nl2[grouped_nl2['Config'] == config]
    color = colors(i)

    # Plot Incumbent mean
    ax.plot(config_data['Node'], config_data['Incumbent_mean'], label=f'Config {config} - Incumbent', color=color)
    # Add shaded area for Incumbent std
    ax.fill_between(config_data['Node'], 
                    config_data['Incumbent_mean'] - config_data['Incumbent_std'], 
                    config_data['Incumbent_mean'] + config_data['Incumbent_std'], 
                    color=color, alpha=0.2)

    # Plot BestBd mean
    ax.plot(config_data['Node'], config_data['BestBd_mean'], linestyle='--', label=f'Config {config} - BestBd', color=color)
    # Add shaded area for BestBd std
    ax.fill_between(config_data['Node'], 
                    config_data['BestBd_mean'] - config_data['BestBd_std'], 
                    config_data['BestBd_mean'] + config_data['BestBd_std'], 
                    color=color, alpha=0.2)

    # Set log scale and axis limits
    ax.set_yscale('log')
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)

    # Add labels and grid
    ax.set_xlabel('Nodes')
    ax.set_ylabel('Objective Value')
    ax.grid(True)
    ax.legend()

# Set the title for the entire figure
fig.suptitle('Bound Convergence Over Nodes (Log Scale)', fontsize=16)

# Adjust layout to prevent overlapping
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Show the plot
plt.show()

# Optionally, save the figure
PATH = r"C:\Users\sian_\OneDrive\Documents\Thesis"
plt.savefig(PATH + r'\images\bound_convergence_nodes_subplots.png')
