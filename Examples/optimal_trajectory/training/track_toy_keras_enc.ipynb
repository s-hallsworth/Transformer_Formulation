# %% [markdown]
# # Train Optimall Trajectory Transformer

# %%
import torch
import math
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
# following: https://www.geeksforgeeks.org/time-series-forecasting-using-pytorch/

# Read data
T = 1
path = f"..\\data\\data_T{str(T)}.csv"
names = ['time', 'x1' , 'x2','obs_num']
df = pd.read_csv(path,sep=',', header=0, names=names,index_col=False)
print(df.head())
print(df.shape)

obs = max(df['obs_num'])
print("Number of different trajectory functions",int(obs))
# Out:
#        time        x1        x2  obs_num
# 0  0.000000  0.000000  0.000000      1.0
# 1  0.026316  0.016014  0.007989      1.0
# 2  0.052632  0.032028  0.009184      1.0
# 3  0.078947  0.048042  0.003586      1.0
# 4  0.105263  0.064057 -0.008806      1.0
# (11400, 4)
# Number of different trajectory functions 300

# %%
# Train test split

train_data = df[df['time']< (0.7 * T)]
test_data = df[df['time']>= (0.7 * T)]
print("train shape, test shape: ",train_data.shape, test_data.shape)
print(train_data.head())

train_times = df[df['time']< (0.7 * T)]["time"].tolist()
test_times =  df[df['time']>= (0.7 * T)]["time"].tolist()
# print("train times: ", train_times)
# print("test times: ", test_times)
# Out:
# train shape, test shape:  (8100, 4) (3300, 4)
#        time        x1        x2  obs_num
# 0  0.000000  0.000000  0.000000      1.0
# 1  0.026316  0.016014  0.007989      1.0
# 2  0.052632  0.032028  0.009184      1.0
# 3  0.078947  0.048042  0.003586      1.0
# 4  0.105263  0.064057 -0.008806      1.0

# %%
# scaler = MinMaxScaler(feature_range=(0, 1)) # StandardScaler() # 

# # Scaling dataset
# scaled_train = scaler.fit_transform(train_data.to_numpy())
# scaled_train = pd.DataFrame(scaled_train, columns=names)
# print(scaled_train.shape)
# print(scaled_train.head())

# scaled_test = scaler.fit_transform(test_data.to_numpy())
# scaled_test = pd.DataFrame(scaled_test, columns=names)
# print(scaled_test.shape)

# %%
scaled_train = train_data
scaled_test = test_data

# %%
# define positional encoding
# def positional_encoding(T, d_model):
#     # Initialize positional encoding matrix
#     t= np.linspace(0, 1, num=T)
#     pe = np.zeros((t.shape[0], d_model))
    
#     # Compute positional encodings
#     for pos, time in enumerate(t):
#         for i in range(d_model):
#             if i % 2 == 0:
#                 pe[pos, i] = np.sin(time / (10000 ** (2 * i / d_model)))
#             else:
#                 pe[pos, i] = np.cos(time / (10000 ** (2 * (i-1) / d_model)))
    
#     return np.array(pe)



# ## Save data
# ID = []
# PE = []
# d_model  = 1
# N = 10

# for i in range(N):
#     PE += [positional_encoding(T-1, d_model)[:,d_model-1]]

# PE = np.array(PE)
# print(PE)
# PE= PE.flatten()
# print(PE.shape)

# %%
# PE_train = PE[:training_data_len]
# PE_test  = PE[training_data_len:]

# scaled_train["u"] = scaled_train["u"] + PE_train
# scaled_train["dx_dt"] = scaled_train["dx_dt"] + PE_train

# scaled_test["u"] = scaled_test["u"] + PE_test
# scaled_test["dx_dt"] = scaled_test["dx_dt"] + PE_test

# print(scaled_train.head())
# print(scaled_test.head())

# %%
# Create sequences
def to_sequences(seq_size, df, pred_len):
    x = []
    y = []
    times_x = []
    times_y = []
    
    overlap = 1 #seq_size - pred_len
    for obs in df['obs_num'].unique():
        df_obs = df[df['obs_num']==obs]
        obs_x1 = df_obs['x1'].tolist()
        obs_x2 = df_obs['x2'].tolist()
        t = df_obs['time'].tolist()
        for i in range((len(obs_x1))-seq_size-pred_len) : #create input and pred windows based on trajectory function
            
            window1 = obs_x1[i:(i+seq_size)]  # x at time t
            window2 = obs_x2[i:(i+seq_size)]  # u at time t
            t_x = t[i:(i+seq_size)]
        
            after_window1 = obs_x1[i+seq_size-overlap : i+seq_size+pred_len]  # delta x at time t+1 ( x_t+1 - x_t = delta_x_t+1)
            after_window2 = obs_x2[i+seq_size-overlap : i+seq_size+pred_len]
            t_y = t[i+seq_size-overlap : i+seq_size+pred_len]
            
            window = [[x, u] for x,u in zip(window1, window2)]
            after_window = [[x, u] for x,u in zip(after_window1, after_window2)]
            
            x.append(window)
            y.append(after_window)
            
            
            times_x.append(t_x)
            times_y.append(t_y)

    #return np.array(x).transpose((0,2,1)), np.array(y).transpose(0,2,1)
    return np.array(x), np.array(y), np.array(times_x), np.array(times_y)
pred_len = 1
sequence_size = 2

X_train, y_train, X_train_times, y_train_times = to_sequences(sequence_size, scaled_train, pred_len)


# Convert data to PyTorch tensors
# X_train = torch.tensor(X_train, dtype=torch.float32)
# y_train = torch.tensor(y_train, dtype=torch.float32)
# print(X_train.shape, y_train.shape)

# Create sequences and labels for testing data
X_test,  y_test, X_test_times, y_test_times  = to_sequences(sequence_size, scaled_test, pred_len)
# Convert data to PyTorch tensors
# X_test = torch.tensor(X_test, dtype=torch.float32)
# y_test = torch.tensor(y_test, dtype=torch.float32)
# print(X_test.shape, y_test.shape)

# %%
# from torch.utils.data import Dataset, DataLoader
# batch_size = 128
# class TimeSeriesDataset(Dataset):
#     def __init__(self, X, Y):
#         self.X = X
#         self.Y = Y

#     def __len__(self):
#         return len(self.X)

#     def __getitem__(self, idx):
#         return self.X[idx], self.Y[idx]

# train_dataset = TimeSeriesDataset(X_train, y_train)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
from tensorflow import keras
from tensorflow.keras import layers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    ## NB dropout layer is only applied during training not inference (https://keras.io/api/layers/regularization_layers/dropout/)
    
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    # x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    # x = layers.Dropout(dropout)(x)
    # x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)

    x = layers.Dense(ff_dim, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(inputs.shape[-1], activation=None)(x)
    
    #x = layers.Conv2D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    #x = layers.Dropout(dropout)(x)
    #x = layers.Conv2D(filters=inputs.shape[-1], kernel_size=1)(x)

    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0.25,
    mlp_dropout=0.25,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    #x = layers.Dense(8)(x)
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    #x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    #x = layers.GlobalAveragePooling2D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(2, activation=None)(x)
    return keras.Model(inputs, outputs)

# %%
# model parameters:
model_params = {
    'input_shape': (sequence_size,2),
    'head_size':4,
    'num_heads': 1,
    'ff_dim': 32, #32
    'num_transformer_blocks': 1,
    'mlp_units': [24], #24
    'mlp_dropout': 0.05,
    'dropout': 0.05,
    'validation_split': 0.2,
    'epochs':3000,
    'batch_size': 64,
    'learning_rate': 1e-4
}

# %%
model = build_model(
    input_shape = model_params["input_shape"],
    head_size = model_params["head_size"],
    num_heads = model_params["num_heads"],
    ff_dim = model_params["ff_dim"],
    num_transformer_blocks = model_params['num_transformer_blocks'],
    mlp_units = model_params["mlp_units"],
    mlp_dropout = model_params["mlp_dropout"],
    dropout = model_params["dropout"],
)

model.compile(
    loss="mean_absolute_percentage_error",
    optimizer=keras.optimizers.Adam(learning_rate=model_params['learning_rate'])
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=5, \
    restore_best_weights=True)]

model.fit(
    X_train,
    y_train,
    validation_split = model_params["validation_split"],
    epochs = model_params["epochs"],
    batch_size = model_params["batch_size"],
    #callbacks=callbacks,
    shuffle=True,
)
model.evaluate(X_test, y_test) #, verbose=1)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 2, 2)]               0         []
#
#  layer_normalization_2 (Lay  (None, 2, 2)                 4         ['input_2[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 2, 2)                 46        ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  dropout_3 (Dropout)         (None, 2, 2)                 0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 2, 2)                 0         ['dropout_3[0][0]',
#  OpLambda)                                                           'input_2[0][0]']
#
#  layer_normalization_3 (Lay  (None, 2, 2)                 4         ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  dense_4 (Dense)             (None, 2, 32)                96        ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 2, 32)                0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 2, 2)                 66        ['dropout_4[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 2, 2)                 0         ['dense_5[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 2, 24)                72        ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 2, 24)                0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 2, 2)                 50        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 338 (1.32 KB)
# Trainable params: 338 (1.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/3000
# WARNING:tensorflow:From c:\Users\sian_\OneDrive\Documents\Thesis\Transformer_Formulation\pyomo_env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 90/90 [==============================] - 3s 10ms/step - loss: 501.8493 - val_loss: 362.0554
# Epoch 2/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 359.7715 - val_loss: 235.1812
# Epoch 3/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 293.1369 - val_loss: 148.6835
# Epoch 4/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 216.4276 - val_loss: 134.8229
# Epoch 5/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 211.4439 - val_loss: 114.4741
# Epoch 6/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 203.5046 - val_loss: 114.8244
# Epoch 7/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 194.1575 - val_loss: 110.1304
# Epoch 8/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 182.4029 - val_loss: 105.0666
# Epoch 9/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 181.2333 - val_loss: 108.8610
# Epoch 10/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 174.4496 - val_loss: 103.3809
# Epoch 11/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 165.5473 - val_loss: 104.5180
# Epoch 12/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 164.8271 - val_loss: 103.2521
# Epoch 13/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 173.7579 - val_loss: 103.1669
# Epoch 14/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 173.5840 - val_loss: 102.1775
# Epoch 15/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 159.7753 - val_loss: 103.9699
# Epoch 16/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 152.9291 - val_loss: 103.6315
# Epoch 17/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 147.8443 - val_loss: 104.5220
# Epoch 18/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 156.0941 - val_loss: 100.6840
# Epoch 19/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 146.6967 - val_loss: 102.0147
# Epoch 20/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 149.2435 - val_loss: 102.6518
# Epoch 21/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 151.0488 - val_loss: 102.1261
# Epoch 22/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 154.7029 - val_loss: 99.5368
# Epoch 23/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 142.3883 - val_loss: 98.8215
# Epoch 24/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 135.0072 - val_loss: 98.3582
# Epoch 25/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 133.6129 - val_loss: 98.4236
# Epoch 26/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 138.0881 - val_loss: 98.9008
# Epoch 27/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 131.5497 - val_loss: 99.6180
# Epoch 28/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 126.4856 - val_loss: 98.8854
# Epoch 29/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 130.6485 - val_loss: 98.7574
# Epoch 30/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 129.3570 - val_loss: 98.2410
# Epoch 31/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 125.1275 - val_loss: 100.2973
# Epoch 32/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 125.5924 - val_loss: 101.1666
# Epoch 33/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 126.2278 - val_loss: 98.1061
# Epoch 34/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 125.3670 - val_loss: 98.2037
# Epoch 35/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 121.8280 - val_loss: 97.8779
# Epoch 36/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 120.5179 - val_loss: 98.3127
# Epoch 37/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 125.0177 - val_loss: 99.2740
# Epoch 38/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 125.5601 - val_loss: 99.2462
# Epoch 39/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 120.8290 - val_loss: 99.4750
# Epoch 40/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 124.7773 - val_loss: 98.5365
# Epoch 41/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 117.4922 - val_loss: 99.4477
# Epoch 42/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 122.2361 - val_loss: 97.6621
# Epoch 43/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 116.8745 - val_loss: 97.9579
# Epoch 44/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 114.3992 - val_loss: 98.2445
# Epoch 45/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 113.8218 - val_loss: 97.9071
# Epoch 46/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 114.8079 - val_loss: 97.4637
# Epoch 47/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 112.2782 - val_loss: 97.9896
# Epoch 48/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 116.7604 - val_loss: 98.2775
# Epoch 49/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 113.8304 - val_loss: 97.6688
# Epoch 50/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 113.9940 - val_loss: 98.3400
# Epoch 51/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 110.9043 - val_loss: 96.7215
# Epoch 52/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 113.7062 - val_loss: 97.9286
# Epoch 53/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 113.3040 - val_loss: 98.2651
# Epoch 54/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 111.6149 - val_loss: 98.7355
# Epoch 55/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 116.7101 - val_loss: 97.9500
# Epoch 56/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 113.1804 - val_loss: 98.2137
# Epoch 57/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 111.6407 - val_loss: 98.1762
# Epoch 58/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 110.9689 - val_loss: 97.6202
# Epoch 59/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 112.7827 - val_loss: 97.3107
# Epoch 60/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 110.6368 - val_loss: 98.2304
# Epoch 61/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 113.5642 - val_loss: 97.4292
# Epoch 62/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 115.6292 - val_loss: 100.2119
# Epoch 63/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 109.8636 - val_loss: 96.6065
# Epoch 64/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 108.6763 - val_loss: 97.7291
# Epoch 65/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 108.8627 - val_loss: 95.9873
# Epoch 66/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 114.3634 - val_loss: 96.9060
# Epoch 67/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 105.3663 - val_loss: 96.0716
# Epoch 68/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 108.2281 - val_loss: 96.3049
# Epoch 69/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 108.2215 - val_loss: 96.4656
# Epoch 70/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 109.9553 - val_loss: 97.3512
# Epoch 71/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 108.1596 - val_loss: 96.4697
# Epoch 72/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 109.3064 - val_loss: 96.4567
# Epoch 73/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 109.9821 - val_loss: 96.5922
# Epoch 74/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 108.2624 - val_loss: 97.2231
# Epoch 75/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 113.0241 - val_loss: 96.1628
# Epoch 76/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 104.0074 - val_loss: 94.9546
# Epoch 77/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 107.5929 - val_loss: 96.5898
# Epoch 78/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 110.4940 - val_loss: 95.4456
# Epoch 79/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 103.5163 - val_loss: 95.2677
# Epoch 80/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 107.3524 - val_loss: 96.4270
# Epoch 81/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 108.8883 - val_loss: 95.0833
# Epoch 82/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 105.9412 - val_loss: 96.7939
# Epoch 83/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 106.0467 - val_loss: 95.4329
# Epoch 84/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 107.0334 - val_loss: 96.8552
# Epoch 85/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 106.8032 - val_loss: 94.6832
# Epoch 86/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 102.0594 - val_loss: 94.5197
# Epoch 87/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 103.8807 - val_loss: 95.1190
# Epoch 88/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 105.9100 - val_loss: 96.0094
# Epoch 89/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 105.7901 - val_loss: 94.3699
# Epoch 90/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 101.0720 - val_loss: 93.6921
# Epoch 91/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 103.4279 - val_loss: 93.2026
# Epoch 92/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 101.0071 - val_loss: 92.5015
# Epoch 93/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 103.2283 - val_loss: 91.8842
# Epoch 94/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 101.2503 - val_loss: 92.4100
# Epoch 95/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 99.9028 - val_loss: 90.9239
# Epoch 96/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 99.7423 - val_loss: 92.0937
# Epoch 97/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 101.9709 - val_loss: 89.6603
# Epoch 98/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 100.1044 - val_loss: 90.5705
# Epoch 99/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 98.2942 - val_loss: 89.2185
# Epoch 100/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 95.4690 - val_loss: 88.4232
# Epoch 101/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 100.4798 - val_loss: 87.5625
# Epoch 102/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 98.4868 - val_loss: 87.0809
# Epoch 103/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 97.6945 - val_loss: 88.1530
# Epoch 104/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 95.7574 - val_loss: 88.0905
# Epoch 105/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 95.3252 - val_loss: 86.1575
# Epoch 106/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 94.2125 - val_loss: 85.7317
# Epoch 107/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 94.5521 - val_loss: 84.4891
# Epoch 108/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 95.1144 - val_loss: 85.9180
# Epoch 109/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 94.0293 - val_loss: 83.3556
# Epoch 110/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 95.9698 - val_loss: 83.2433
# Epoch 111/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 93.2807 - val_loss: 82.7639
# Epoch 112/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 94.8940 - val_loss: 81.6219
# Epoch 113/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 93.6726 - val_loss: 83.5594
# Epoch 114/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 93.0910 - val_loss: 82.4825
# Epoch 115/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 92.8439 - val_loss: 83.5780
# Epoch 116/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 94.0625 - val_loss: 84.4486
# Epoch 117/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 90.4760 - val_loss: 83.5451
# Epoch 118/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 93.7366 - val_loss: 84.6284
# Epoch 119/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 92.2119 - val_loss: 81.0434
# Epoch 120/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 91.5546 - val_loss: 82.1969
# Epoch 121/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 91.3038 - val_loss: 81.2484
# Epoch 122/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 95.8471 - val_loss: 83.9973
# Epoch 123/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 95.2336 - val_loss: 83.4589
# Epoch 124/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 93.5987 - val_loss: 82.9331
# Epoch 125/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 95.2553 - val_loss: 83.0779
# Epoch 126/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 92.0557 - val_loss: 81.0829
# Epoch 127/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 93.1550 - val_loss: 80.2898
# Epoch 128/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 89.8391 - val_loss: 78.5059
# Epoch 129/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 86.4701 - val_loss: 79.4885
# Epoch 130/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 89.6343 - val_loss: 78.4323
# Epoch 131/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 88.8403 - val_loss: 79.3687
# Epoch 132/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 92.6925 - val_loss: 79.3894
# Epoch 133/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 88.6441 - val_loss: 79.0191
# Epoch 134/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 87.0234 - val_loss: 77.4986
# Epoch 135/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 90.6583 - val_loss: 77.1606
# Epoch 136/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 87.4601 - val_loss: 78.3730
# Epoch 137/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 86.1413 - val_loss: 77.1838
# Epoch 138/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 90.0699 - val_loss: 76.8399
# Epoch 139/3000
# 90/90 [==============================] - 0s 5ms/step - loss:
3000
# 90/90 [==============================] - 0s 5ms/step - loss: 69.9900 - val_loss: 63.8148
# Epoch 196/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 69.6734 - val_loss: 59.9786
# Epoch 197/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 71.8115 - val_loss: 59.7281
# Epoch 198/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 71.7778 - val_loss: 60.9908
# Epoch 199/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 70.1184 - val_loss: 61.5964
# Epoch 200/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 69.7456 - val_loss: 62.5727
# Epoch 201/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 70.9572 - val_loss: 60.3086
# Epoch 202/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 73.7291 - val_loss: 63.0816
# Epoch 203/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 69.3200 - val_loss: 60.4441
# Epoch 204/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 68.7086 - val_loss: 58.5090
# Epoch 205/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 70.0737 - val_loss: 59.6775
# Epoch 206/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 69.3843 - val_loss: 59.3149
# Epoch 207/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 71.0062 - val_loss: 60.1800
# Epoch 208/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 67.8017 - val_loss: 62.9481
# Epoch 209/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 69.1361 - val_loss: 60.6456
# Epoch 210/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 68.3545 - val_loss: 57.6071
# Epoch 211/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 67.7314 - val_loss: 58.9678
# Epoch 212/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 66.4626 - val_loss: 58.0526
# Epoch 213/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 67.5540 - val_loss: 57.9427
# Epoch 214/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 66.6616 - val_loss: 56.4862
# Epoch 215/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 67.2714 - val_loss: 57.0566
# Epoch 216/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 67.7354 - val_loss: 56.1700
# Epoch 217/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 67.4754 - val_loss: 60.0845
# Epoch 218/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 69.0672 - val_loss: 57.3326
# Epoch 219/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.4413 - val_loss: 57.7999
# Epoch 220/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.7762 - val_loss: 60.0188
# Epoch 221/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.4128 - val_loss: 57.9834
# Epoch 222/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.2397 - val_loss: 57.1586
# Epoch 223/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.7087 - val_loss: 56.7592
# Epoch 224/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.8222 - val_loss: 57.6212
# Epoch 225/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 67.6944 - val_loss: 55.7455
# Epoch 226/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 64.5379 - val_loss: 55.4296
# Epoch 227/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 65.9088 - val_loss: 56.4580
# Epoch 228/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 64.7397 - val_loss: 56.2788
# Epoch 229/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 67.1146 - val_loss: 54.3418
# Epoch 230/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 66.7897 - val_loss: 55.4542
# Epoch 231/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 65.0832 - val_loss: 57.3880
# Epoch 232/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 63.6350 - val_loss: 54.3435
# Epoch 233/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 64.7678 - val_loss: 54.3081
# Epoch 234/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 65.0782 - val_loss: 54.4990
# Epoch 235/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 63.1880 - val_loss: 53.1600
# Epoch 236/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 63.0692 - val_loss: 54.8147
# Epoch 237/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 61.2364 - val_loss: 53.6474
# Epoch 238/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 62.1486 - val_loss: 52.2548
# Epoch 239/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 60.8208 - val_loss: 55.2262
# Epoch 240/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 59.8539 - val_loss: 53.5142
# Epoch 241/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 62.8684 - val_loss: 52.5551
# Epoch 242/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 61.6023 - val_loss: 52.4155
# Epoch 243/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 61.7318 - val_loss: 51.7066
# Epoch 244/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 61.7591 - val_loss: 55.3600
# Epoch 245/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 61.6081 - val_loss: 53.9774
# Epoch 246/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 59.2509 - val_loss: 51.1556
# Epoch 247/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 58.5669 - val_loss: 50.6890
# Epoch 248/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 59.8260 - val_loss: 51.2886
# Epoch 249/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 60.0244 - val_loss: 49.5378
# Epoch 250/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 60.8739 - val_loss: 50.0688
# Epoch 251/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 57.2358 - val_loss: 52.6953
# Epoch 252/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 56.7369 - val_loss: 49.8638
# Epoch 253/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 59.0740 - val_loss: 51.2779
# Epoch 254/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 57.2593 - val_loss: 47.2844
# Epoch 255/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 56.8734 - val_loss: 48.9134
# Epoch 256/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 55.8250 - val_loss: 47.6332
# Epoch 257/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 56.0017 - val_loss: 46.5817
# Epoch 258/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 54.5434 - val_loss: 48.5544
# Epoch 259/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 54.6730 - val_loss: 47.5567
# Epoch 260/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 54.6900 - val_loss: 46.8683
# Epoch 261/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 53.5766 - val_loss: 45.5938
# Epoch 262/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 53.1297 - val_loss: 45.6472
# Epoch 263/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 55.4642 - val_loss: 48.2395
# Epoch 264/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 51.7623 - val_loss: 44.0460
# Epoch 265/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 53.2832 - val_loss: 45.0501
# Epoch 266/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 51.1828 - val_loss: 46.4513
# Epoch 267/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 51.8341 - val_loss: 43.0476
# Epoch 268/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 53.2882 - val_loss: 44.0095
# Epoch 269/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 51.0111 - val_loss: 41.7681
# Epoch 270/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 52.4567 - val_loss: 42.7511
# Epoch 271/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 51.1930 - val_loss: 42.0795
# Epoch 272/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 50.6162 - val_loss: 41.2865
# Epoch 273/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 48.8176 - val_loss: 40.5930
# Epoch 274/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 49.4908 - val_loss: 41.8191
# Epoch 275/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 47.3121 - val_loss: 39.3110
# Epoch 276/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 49.0828 - val_loss: 43.0446
# Epoch 277/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.8038 - val_loss: 38.8989
# Epoch 278/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 47.3583 - val_loss: 40.7676
# Epoch 279/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 47.0380 - val_loss: 36.4032
# Epoch 280/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 48.5596 - val_loss: 39.1676
# Epoch 281/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.1105 - val_loss: 36.6666
# Epoch 282/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 46.3199 - val_loss: 35.4733
# Epoch 283/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.2081 - val_loss: 36.4329
# Epoch 284/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.5490 - val_loss: 36.5876
# Epoch 285/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 43.4610 - val_loss: 37.5668
# Epoch 286/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 44.3893 - val_loss: 35.0877
# Epoch 287/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.4531 - val_loss: 35.5734
# Epoch 288/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.5962 - val_loss: 34.0675
# Epoch 289/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 42.6818 - val_loss: 33.2145
# Epoch 290/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 40.3265 - val_loss: 32.7515
# Epoch 291/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 45.6149 - val_loss: 32.4067
# Epoch 292/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 42.9914 - val_loss: 32.3576
# Epoch 293/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 41.4027 - val_loss: 31.5316
# Epoch 294/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 43.7425 - val_loss: 31.5352
# Epoch 295/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 42.7912 - val_loss: 34.3790
# Epoch 296/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 39.8871 - val_loss: 31.4376
# Epoch 297/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 42.6625 - val_loss: 29.5499
# Epoch 298/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 40.6243 - val_loss: 29.5462
# Epoch 299/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 41.7767 - val_loss: 29.8337
# Epoch 300/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 39.9075 - val_loss: 29.2847
# Epoch 301/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.6666 - val_loss: 28.6246
# Epoch 302/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 40.0330 - val_loss: 31.5231
# Epoch 303/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.7782 - val_loss: 30.8443
# Epoch 304/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 40.5843 - val_loss: 29.8046
# Epoch 305/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 39.7564 - val_loss: 29.5024
# Epoch 306/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.9124 - val_loss: 29.6584
# Epoch 307/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 36.8279 - val_loss: 28.8184
# Epoch 308/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 41.1730 - val_loss: 27.2331
# Epoch 309/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 39.3586 - val_loss: 28.5591
# Epoch 310/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.4113 - val_loss: 27.7623
# Epoch 311/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 37.3836 - val_loss: 26.4968
# Epoch 312/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.1492 - val_loss: 25.9860
# Epoch 313/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 37.7601 - val_loss: 26.8087
# Epoch 314/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.5762 - val_loss: 28.7990
# Epoch 315/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 36.1371 - val_loss: 26.6670
# Epoch 316/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 39.1184 - val_loss: 25.8566
# Epoch 317/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.1204 - val_loss: 27.1249
# Epoch 318/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 38.1469 - val_loss: 25.6861
# Epoch 319/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 36.4269 - val_loss: 24.7700
# Epoch 320/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 37.6336 - val_loss: 28.7025
# Epoch 321/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 36.9310 - val_loss: 26.6925
# Epoch 322/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 34.5451 - val_loss: 25.6924
# Epoch 323/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 36.3114 - val_loss: 25.1752
# Epoch 324/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 36.1220 - val_loss: 24.5447
# Epoch 325/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 33.9471 - val_loss: 26.4767
# Epoch 326/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.2587 - val_loss: 24.7928
# Epoch 327/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.2586 - val_loss: 27.7257
# Epoch 328/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 36.3612 - val_loss: 24.2122
# Epoch 329/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.5920 - val_loss: 25.7868
# Epoch 330/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 34.5854 - val_loss: 25.1733
# Epoch 331/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.9704 - val_loss: 25.3193
# Epoch 332/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 32.7257 - val_loss: 23.6006
# Epoch 333/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 34.1919 - val_loss: 24.8119
# Epoch 334/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 33.4656 - val_loss: 24.6993
# Epoch 335/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 37.2670 - val_loss: 23.2431
# Epoch 336/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 36.1660 - val_loss: 24.6133
# Epoch 337/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.5805 - val_loss: 24.8564
# Epoch 338/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 33.6115 - val_loss: 24.9530
# Epoch 339/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.1754 - val_loss: 23.8415
# Epoch 340/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 33.6293 - val_loss: 22.9571
# Epoch 341/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 34.3409 - val_loss: 23.9283
# Epoch 342/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 31.3794 - val_loss: 22.9141
# Epoch 343/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 33.0178 - val_loss: 22.7440
# Epoch 344/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 34.4261 - val_loss: 23.9141
# Epoch 345/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.2298 - val_loss: 30.9208
# Epoch 346/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 34.4207 - val_loss: 22.1083
# Epoch 347/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 31.8410 - val_loss: 22.2433
# Epoch 348/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.2618 - val_loss: 22.7582
# Epoch 349/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 29.8544 - val_loss: 23.0908
# Epoch 350/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 30.7543 - val_loss: 23.3775
# Epoch 351/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 35.3136 - val_loss: 24.0598
# Epoch 352/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 31.0148 - val_loss: 22.3833
# Epoch 353/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 31.4958 - val_loss: 23.5964
# Epoch 354/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.8097 - val_loss: 24.1715
# Epoch 355/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.9224 - val_loss: 21.9166
# Epoch 356/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.7035 - val_loss: 22.2130
# Epoch 357/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.7222 - val_loss: 25.2168
# Epoch 358/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 33.5172 - val_loss: 23.1885
# Epoch 359/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.8482 - val_loss: 21.5114
# Epoch 360/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.3367 - val_loss: 21.0289
# Epoch 361/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.7971 - val_loss: 21.8030
# Epoch 362/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.8097 - val_loss: 22.8741
# Epoch 363/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 33.7598 - val_loss: 24.4796
# Epoch 364/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.1127 - val_loss: 21.0100
# Epoch 365/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.1697 - val_loss: 21.7770
# Epoch 366/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.7784 - val_loss: 23.1191
# Epoch 367/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.6072 - val_loss: 21.4126
# Epoch 368/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.3451 - val_loss: 21.7986
# Epoch 369/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.2228 - val_loss: 21.1338
# Epoch 370/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 30.2949 - val_loss: 22.0980
# Epoch 371/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 29.3386 - val_loss: 20.9814
# Epoch 372/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 29.9148 - val_loss: 21.0719
# Epoch 373/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 29.2369 - val_loss: 20.5424
# Epoch 374/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.6938 - val_loss: 21.1199
# Epoch 375/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.1737 - val_loss: 20.8978
# Epoch 376/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.0252 - val_loss: 20.4938
# Epoch 377/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.1913 - val_loss: 24.2097
# Epoch 378/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.7261 - val_loss: 21.1611
# Epoch 379/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.1125 - val_loss: 21.3013
# Epoch 380/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 32.4591 - val_loss: 21.2174
# Epoch 381/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.7658 - val_loss: 21.5758
# Epoch 382/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 31.0044 - val_loss: 21.5609
# Epoch 383/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.8862 - val_loss: 20.7123
# Epoch 384/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.0489 - val_loss: 22.2806
# Epoch 385/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 28.6562 - val_loss: 21.2613
# Epoch 386/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 30.0020 - val_loss: 21.8974
# Epoch 387/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.5100 - val_loss: 21.2053
# Epoch 388/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 27.3921 - val_loss: 21.5200
# Epoch 389/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.6622 - val_loss: 21.1167
# Epoch 390/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.0692 - val_loss: 21.4261
# Epoch 391/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 28.3840 - val_loss: 21.6251
# Epoch 392/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 28.9580 - val_loss: 20.6934
# Epoch 393/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.9813 - val_loss: 24.1003
# Epoch 394/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 28.7946 - val_loss: 20.9079
# Epoch 395/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.3856 - val_loss: 21.8452
# Epoch 396/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.9512 - val_loss: 25.0621
# Epoch 397/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.9771 - val_loss: 20.5160
# Epoch 398/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.2649 - val_loss: 20.2596
# Epoch 399/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 29.9817 - val_loss: 22.6260
# Epoch 400/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 28.8340 - val_loss: 20.7878
# Epoch 401/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 30.3424 - val_loss: 23.7769
# Epoch 402/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.3544 - val_loss: 22.4893
# Epoch 403/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 27.4155 - val_loss: 20.6326
# Epoch 404/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.4473 - val_loss: 20.5517
# Epoch 405/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 29.0326 - val_loss: 21.5225
# Epoch 406/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 27.4277 - val_loss: 20.6361
# Epoch 407/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 27.7315 - val_loss: 20.0953
# Epoch 408/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 27.5738 - val_loss: 21.4018
# Epoch 409/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.7140 - val_loss: 21.2584
# Epoch 410/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.0412 - val_loss: 21.5923
# Epoch 411/3000
# 90/90 [==============================] - 0s 6ms/step - loss: 28.1726 - val_loss: 21.2326
# Epoch 412/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 27.8012 - val_loss: 22.8572
# Epoch 413/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 28.6931 - val_loss: 22.3063
# Epoch 414/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 26.4200 - val_loss: 21.1682
# Epoch 415/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 29.0499 - val_loss: 20.3739
# Epoch 416/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 28.4365 - val_loss: 21.2565
# Epoch 417/3000
# 90/90 [==============================] - 0s 5ms/step - loss: 27.4851 - val_loss: 21.1332
# Epoch 418/3000
# 90/90 [==============================] - 1s 6ms/step - loss: 27.7533 - val_loss: 23.5347
# Epoch 419/3000
# ...
# Epoch 2850/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18
3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.5252 - val_loss: 18.1589
# Epoch 2973/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.2833 - val_loss: 17.7613
# Epoch 2974/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.1624 - val_loss: 16.3004
# Epoch 2975/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.2407 - val_loss: 16.3574
# Epoch 2976/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 19.0744 - val_loss: 17.3221
# Epoch 2977/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.8392 - val_loss: 17.4791
# Epoch 2978/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.6953 - val_loss: 16.2038
# Epoch 2979/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.7699 - val_loss: 17.0213
# Epoch 2980/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 19.6293 - val_loss: 16.7618
# Epoch 2981/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.1519 - val_loss: 17.3904
# Epoch 2982/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.5841 - val_loss: 16.9457
# Epoch 2983/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 18.0054 - val_loss: 17.0089
# Epoch 2984/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.7924 - val_loss: 16.4197
# Epoch 2985/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.1118 - val_loss: 16.4850
# Epoch 2986/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.6884 - val_loss: 17.3054
# Epoch 2987/3000
# 90/90 [==============================] - 0s 4ms/step - loss: 18.6250 - val_loss: 17.6787
# Epoch 2988/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.4107 - val_loss: 17.0733
# Epoch 2989/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.1276 - val_loss: 16.5101
# Epoch 2990/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.3893 - val_loss: 16.3826
# Epoch 2991/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.8676 - val_loss: 16.9183
# Epoch 2992/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.9461 - val_loss: 16.7348
# Epoch 2993/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.5691 - val_loss: 16.8596
# Epoch 2994/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.7553 - val_loss: 19.6922
# Epoch 2995/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.3017 - val_loss: 15.9926
# Epoch 2996/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.7182 - val_loss: 17.8999
# Epoch 2997/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.3647 - val_loss: 18.2299
# Epoch 2998/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 17.9290 - val_loss: 16.3256
# Epoch 2999/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.4751 - val_loss: 18.7842
# Epoch 3000/3000
# 90/90 [==============================] - 0s 3ms/step - loss: 18.1207 - val_loss: 17.9611
# 75/75 [==============================] - 0s 1ms/step - loss: 5.4460
# 5.445965766906738

# %%
name = 'TNN_traj_enc_3.keras'
model.save(name , overwrite=True)

# %%
output = model.predict(X_test)
print(output)
# Out:
# 75/75 [==============================] - 0s 1ms/step
# [[[ 0.42734176 -2.2412314 ]
#   [ 0.4426108  -2.4171774 ]]
#
#  [[ 0.44261083 -2.4171774 ]
#   [ 0.4578521  -2.5999372 ]]
#
#  [[ 0.45785215 -2.5999372 ]
#   [ 0.47306544 -2.7895103 ]]
#
#  ...
#
#  [[ 0.76807517 -2.72779   ]
#   [ 0.7940825  -2.9231453 ]]
#
#  [[ 0.7940825  -2.9231453 ]
#   [ 0.82023734 -3.1252975 ]]
#
#  [[ 0.82023734 -3.1252975 ]
#   [ 0.84653974 -3.3342476 ]]]

# %%
print(y_test.shape)
print(output.shape)
# Out:
# (2400, 2, 2)
# (2400, 2, 2)

# %%
# display train results
import matplotlib.pyplot as plt

colours = ["r", "b", "g", "m", "c", "tab:orange", "tab:brown", "tab:pink", "tab:gray"]
data_files = ["x1", "y1"]
for i in [0, 100, 200]: # select batches
    for d, name in enumerate(data_files):
    
        plt.figure(i, figsize=(12, 4))
        plt.plot( y_test[i,:,d], "-o",fillstyle="none", color=colours[d], label=f'{name} expected')
        plt.plot( output[i,:,d] , "o", color=colours[d], label=f'{name} predicted')
        
        plt.title(f"Train Results (simuation {i})")
        plt.legend()

# %%
# #save model
model_path = ".\\toy_traj_enc.pt"
torch.save(model.state_dict(), model_path)
