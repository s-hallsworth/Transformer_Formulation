# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_5_keras_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adapted from: https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_5_keras_transformers.ipynb

# %%
import pandas as pd
import numpy as np
import os

names = ['time', 'u' , 'x', 'obs_num']

path = r"C:\Users\sian_\OneDrive\Documents\Thesis\MILP_Formulation\Optimal_Control_Toy"
df = pd.read_csv("data_N200.csv",sep=',', header=0, names=names,index_col=False)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.bfill(inplace=True)
df.ffill(inplace=True) #for obs num


print("Starting file:")
print(df[0:10])

print("Ending file:")
print(df[-10:])

print(df.shape)
# Out:
# Starting file:
#        time         u         x  obs_num
# 0  0.000000  0.250000  1.000000      1.0
# 1  0.000111  0.250014  1.000118      1.0
# 2  0.000222  0.250028  1.000236      1.0
# 3  0.000333  0.250042  1.000354      1.0
# 4  0.000444  0.250056  1.000472      1.0
# 5  0.000556  0.250069  1.000590      1.0
# 6  0.000667  0.250083  1.000708      1.0
# 7  0.000778  0.250097  1.000826      1.0
# 8  0.000889  0.250111  1.000945      1.0
# 9  0.001000  0.250125  1.001063      1.0
# Ending file:
#            time         u         x  obs_num
# 26990  0.999000  1.998000  3.328337      3.0
# 26991  0.999111  1.998222  3.328892      3.0
# 26992  0.999222  1.998444  3.329446      3.0
# 26993  0.999333  1.998667  3.330001      3.0
# 26994  0.999444  1.998889  3.330556      3.0
# 26995  0.999556  1.999111  3.331112      3.0
# 26996  0.999667  1.999333  3.331667      3.0
# 26997  0.999778  1.999556  3.332222      3.0
# 26998  0.999889  1.999778  3.332778      3.0
# 26999  1.000000  2.000000  3.333333      3.0
# (27000, 4)

# %%
# # Find the last zero and move one beyond
# start_id = max(df[df['obs_num'] == 0].index.tolist())+1
# print(start_id)
# df = df[start_id:] # Trim the rows that have missing observations

# %% [markdown]
# Divide into training and test/validation sets.

# %%
df['u'] = df['u'].astype(float)
df12 = df[df['obs_num']<3.0]
df123 = df[df['obs_num']<4.0]

df_train = df123[df123['time']<0.7]
df_test = df123[df123['time']>=0.7]

spots_train_u = df_train['u'].tolist()
spots_train_x = df_train['x'].tolist()
spots_train_t = df_train['time'].tolist()

spots_test_u = df_test['u'].tolist()
spots_test_x = df_test['x'].tolist()
spots_test_t = df_test['time'].tolist()

print("Training set has {} observations.".format(len(spots_train_u)))
print("Test set has {} observations.".format(len(spots_test_u)))
# print(spots_train)
# Out:
# Training set has 18900 observations.
# Test set has 8100 observations.

# %%
df1 = df[df['obs_num']==1.0]
df2 = df[df['obs_num']==2.0]
df3 = df[df['obs_num']==3.0]

df_test1 = df1[df1['time']>=0.7]
df_test2 = df2[df2['time']>=0.7]
df_test3 = df3[df3['time']>=0.7]

spots_test1_u = df_test1['u'].tolist()
spots_test1_x = df_test1['x'].tolist()
spots_test1_t = df_test1['time'].tolist()

spots_test2_x = df_test2['x'].tolist()
spots_test2_u = df_test2['u'].tolist()
spots_test2_t = df_test2['time'].tolist()

spots_test3_x = df_test3['x'].tolist()
spots_test3_u = df_test3['u'].tolist()
spots_test3_t = df_test3['time'].tolist()

print("Test set 1 has {} observations.".format(len(spots_test1_u)))
print("Test set 2 has {} observations.".format(len(spots_test2_u)))
print("Test set 3 has {} observations.".format(len(spots_test3_u)))
# Out:
# Test set 1 has 2700 observations.
# Test set 2 has 2700 observations.
# Test set 3 has 2700 observations.

# %% [markdown]
# The **to_sequences** function takes linear time series data into an **x** and **y** where **x** is all possible sequences of seq_size. After each **x** sequence, this function places the next value into the **y** variable. These **x** and **y** data can train a time-series neural network.

# %%
import numpy as np

def to_sequences(seq_size, obs_x, obs_u, obs_t):

    x = []
    y = []
    for i in range((len(obs_x))-SEQUENCE_SIZE):
        
        window1 = obs_x[i:(i+SEQUENCE_SIZE)] 
        window2 = obs_u[i:(i+SEQUENCE_SIZE)]  #obs_u[SEQUENCE_SIZE-1]  * np.ones(SEQUENCE_SIZE)#obs_u[i:(i+SEQUENCE_SIZE)] 
        #window2 =window2.tolist()
        
        after_window = [obs_x[i+SEQUENCE_SIZE]] 
        window = [[x, t] for x,t in zip(window1, window2)]
        #print("{} - {}".format(window1,after_window))
        x.append(window)
        y.append(after_window)

    return np.array(x),np.array(y)

SEQUENCE_SIZE = 10
x_train,y_train = to_sequences(SEQUENCE_SIZE,spots_train_x, spots_train_u, spots_train_t)
x_test,y_test = to_sequences(SEQUENCE_SIZE,spots_test_x, spots_test_u, spots_test_t)

print("Shape of x train set: {}".format(x_train.shape))
print("Shape of x test set: {}".format(x_test.shape))

print("Shape of y train set: {}".format(y_train.shape))
print("Shape of y test set: {}".format(y_test.shape))
# Out:
# Shape of x train set: (18890, 10, 2)
# Shape of x test set: (8090, 10, 2)
# Shape of y train set: (18890, 1)
# Shape of y test set: (8090, 1)

# %%
x_test1, y_test1 = to_sequences(SEQUENCE_SIZE,spots_test1_x, spots_test1_u ,  spots_test1_t)
print("Shape of y1 test set: {}".format(y_test1.shape))

x_test2, y_test2 = to_sequences(SEQUENCE_SIZE,spots_test2_x, spots_test2_u,  spots_test1_t)
print("Shape of y2 test set: {}".format(y_test2.shape))

x_test3, y_test3 = to_sequences(SEQUENCE_SIZE,spots_test3_x, spots_test3_u,  spots_test1_t)
print("Shape of y3 test set: {}".format(y_test3.shape))
# Out:
# Shape of y1 test set: (2690, 1)
# Shape of y2 test set: (2690, 1)
# Shape of y3 test set: (2690, 1)

# %% [markdown]
# We can view the results of the **to_sequences** encoding of the sunspot data.

# %%
# print('func 1',x_train[0])
# print('func 2',x_train[1])

# %%
#!pip install tensorflow

# %% [markdown]
# Next, we create the transformer_encoder; I obtained this function from a [Keras example](https://keras.io/examples/timeseries/timeseries_transformer_classification/). This layer includes residual connections, layer normalization, and dropout. This resulting layer can be stacked multiple times. We implement the projection layers with the Keras Conv1D.

# %%
from tensorflow import keras
from tensorflow.keras import layers

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    ## NB dropout layer is only applied during training not inference (https://keras.io/api/layers/regularization_layers/dropout/)
    
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    # x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    # x = layers.Dropout(dropout)(x)
    # x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)

    x = layers.Dense(ff_dim, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(inputs.shape[-1], activation="relu")(x)
    
    #x = layers.Conv2D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    #x = layers.Dropout(dropout)(x)
    #x = layers.Conv2D(filters=inputs.shape[-1], kernel_size=1)(x)

    return x + res

# %% [markdown]
# The following function is provided to build the model, including the attention layer.

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0.25,
    mlp_dropout=0.25,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    # x = layers.Dense(25)(x)
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    print(x.shape, x)
    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    #x = layers.GlobalAveragePooling2D(data_format="channels_first")(x)
    print(x.shape, x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1, activation="relu")(x)
    return keras.Model(inputs, outputs)

# %%
# model parameters:
model_params = {
    'input_shape': (SEQUENCE_SIZE,2),
    'head_size': 2,
    'num_heads': 10,
    'ff_dim': 32, #32
    'num_transformer_blocks': 1,
    'mlp_units': [32], #24
    'mlp_dropout': 0.05,
    'dropout': 0.05,
    'validation_split': 0.2,
    'epochs':1000,
    'batch_size': 32,
    'learning_rate': 1e-7
}
"""
model_params = {
    'input_shape': x_train.shape[1:],
    'head_size': 10,
    'num_heads': 4,
    'ff_dim': 4,
    'num_transformer_blocks': 1,
    'mlp_units': [128],
    'mlp_dropout': 0,
    'dropout': 0,
    'validation_split': 0.2,
    'epochs': 200,
    'batch_size': 64,
    'learning_rate': 1e-3
}
"""

print(x_train[0,:,0].shape)
# Out:
# (10,)

# %% [markdown]
# We are now ready to build and train the model.

# %%
model = build_model(
    input_shape = model_params["input_shape"],
    head_size = model_params["head_size"],
    num_heads = model_params["num_heads"],
    ff_dim = model_params["ff_dim"],
    num_transformer_blocks = model_params['num_transformer_blocks'],
    mlp_units = model_params["mlp_units"],
    mlp_dropout = model_params["mlp_dropout"],
    dropout = model_params["dropout"],
)

model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=model_params['learning_rate'])
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=2, \
    restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split = model_params["validation_split"],
    epochs = model_params["epochs"],
    batch_size = model_params["batch_size"],
    callbacks=callbacks,
    shuffle=True,
)

model.evaluate(x_test, y_test) #, verbose=1)
# Out:
# (None, 10, 2) <KerasTensor shape=(None, 10, 2), dtype=float32, sparse=False, name=keras_tensor_329>
# (None, 2) <KerasTensor shape=(None, 2), dtype=float32, sparse=False, name=keras_tensor_330>
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_22      │ (None, 10, 2)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 2)     │          4 │ input_layer_22[0… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 2)     │        222 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_89          │ (None, 10, 2)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 10, 2)     │          0 │ dropout_89[0][0], │
# │                     │                   │            │ input_layer_22[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 2)     │          4 │ add_44[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_100 (Dense)   │ (None, 10, 10)    │         30 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_90          │ (None, 10, 10)    │          0 │ dense_100[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_101 (Dense)   │ (None, 10, 2)     │         22 │ dropout_90[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 10, 2)     │          0 │ dense_101[0][0],  │
# │                     │                   │            │ add_44[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2)         │          0 │ add_45[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_102 (Dense)   │ (None, 128)       │        384 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_91          │ (None, 128)       │          0 │ dense_102[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_103 (Dense)   │ (None, 1)         │        129 │ dropout_91[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 795 (3.11 KB)
#  Trainable params: 795 (3.11 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 1.7400 - val_loss: 2.5160
# Epoch 2/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7447 - val_loss: 2.5130
# Epoch 3/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7384 - val_loss: 2.5101
# Epoch 4/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7378 - val_loss: 2.5071
# Epoch 5/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7394 - val_loss: 2.5041
# Epoch 6/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7341 - val_loss: 2.5011
# Epoch 7/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7385 - val_loss: 2.4981
# Epoch 8/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7432 - val_loss: 2.4951
# Epoch 9/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7258 - val_loss: 2.4921
# Epoch 10/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7213 - val_loss: 2.4891
# Epoch 11/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7258 - val_loss: 2.4861
# Epoch 12/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7229 - val_loss: 2.4831
# Epoch 13/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7308 - val_loss: 2.4801
# Epoch 14/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7305 - val_loss: 2.4771
# Epoch 15/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7250 - val_loss: 2.4741
# Epoch 16/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7195 - val_loss: 2.4711
# Epoch 17/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7171 - val_loss: 2.4680
# Epoch 18/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7180 - val_loss: 2.4650
# Epoch 19/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7108 - val_loss: 2.4620
# Epoch 20/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7172 - val_loss: 2.4590
# Epoch 21/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7214 - val_loss: 2.4560
# Epoch 22/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.7086 - val_loss: 2.4530
# Epoch 23/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7039 - val_loss: 2.4500
# Epoch 24/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7012 - val_loss: 2.4470
# Epoch 25/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.7068 - val_loss: 2.4440
# Epoch 26/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7006 - val_loss: 2.4410
# Epoch 27/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7082 - val_loss: 2.4380
# Epoch 28/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.7022 - val_loss: 2.4350
# Epoch 29/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6945 - val_loss: 2.4320
# Epoch 30/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6997 - val_loss: 2.4290
# Epoch 31/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6824 - val_loss: 2.4260
# Epoch 32/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6972 - val_loss: 2.4230
# Epoch 33/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6872 - val_loss: 2.4200
# Epoch 34/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6910 - val_loss: 2.4170
# Epoch 35/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6875 - val_loss: 2.4140
# Epoch 36/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6811 - val_loss: 2.4110
# Epoch 37/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6857 - val_loss: 2.4080
# Epoch 38/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6863 - val_loss: 2.4050
# Epoch 39/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6748 - val_loss: 2.4020
# Epoch 40/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6706 - val_loss: 2.3990
# Epoch 41/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6805 - val_loss: 2.3960
# Epoch 42/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6795 - val_loss: 2.3930
# Epoch 43/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6705 - val_loss: 2.3900
# Epoch 44/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6670 - val_loss: 2.3870
# Epoch 45/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6668 - val_loss: 2.3841
# Epoch 46/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6666 - val_loss: 2.3811
# Epoch 47/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6671 - val_loss: 2.3781
# Epoch 48/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6656 - val_loss: 2.3751
# Epoch 49/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6618 - val_loss: 2.3721
# Epoch 50/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6533 - val_loss: 2.3691
# Epoch 51/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6555 - val_loss: 2.3661
# Epoch 52/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6597 - val_loss: 2.3631
# Epoch 53/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6536 - val_loss: 2.3602
# Epoch 54/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6526 - val_loss: 2.3572
# Epoch 55/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6497 - val_loss: 2.3542
# Epoch 56/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6409 - val_loss: 2.3512
# Epoch 57/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6507 - val_loss: 2.3482
# Epoch 58/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6475 - val_loss: 2.3452
# Epoch 59/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6318 - val_loss: 2.3422
# Epoch 60/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6492 - val_loss: 2.3392
# Epoch 61/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6407 - val_loss: 2.3363
# Epoch 62/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6305 - val_loss: 2.3333
# Epoch 63/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6355 - val_loss: 2.3303
# Epoch 64/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6274 - val_loss: 2.3273
# Epoch 65/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6297 - val_loss: 2.3243
# Epoch 66/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6222 - val_loss: 2.3213
# Epoch 67/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6315 - val_loss: 2.3183
# Epoch 68/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6347 - val_loss: 2.3154
# Epoch 69/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6300 - val_loss: 2.3124
# Epoch 70/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6241 - val_loss: 2.3094
# Epoch 71/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6255 - val_loss: 2.3064
# Epoch 72/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.6185 - val_loss: 2.3034
# Epoch 73/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6148 - val_loss: 2.3004
# Epoch 74/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.6168 - val_loss: 2.2974
# Epoch 75/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6125 - val_loss: 2.2945
# Epoch 76/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6063 - val_loss: 2.2915
# Epoch 77/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.6094 - val_loss: 2.2885
# Epoch 78/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5998 - val_loss: 2.2855
# Epoch 79/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.6075 - val_loss: 2.2825
# Epoch 80/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.6014 - val_loss: 2.2795
# Epoch 81/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.5975 - val_loss: 2.2766
# Epoch 82/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5951 - val_loss: 2.2736
# Epoch 83/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5970 - val_loss: 2.2706
# Epoch 84/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5916 - val_loss: 2.2676
# Epoch 85/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.5839 - val_loss: 2.2646
# Epoch 86/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1.5925 - val_loss: 2.2616
# Epoch 87/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5923 - val_loss: 2.2586
# Epoch 88/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5873 - val_loss: 2.2557
# Epoch 89/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5832 - val_loss: 2.2527
# Epoch 90/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5870 - val_loss: 2.2497
# Epoch 91/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5834 - val_loss: 2.2467
# Epoch 92/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5767 - val_loss: 2.2437
# Epoch 93/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5774 - val_loss: 2.2407
# Epoch 94/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.5738 - val_loss: 2.2377
# Epoch 95/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5747 - val_loss: 2.2348
# Epoch 96/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5723 - val_loss: 2.2318
# Epoch 97/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5691 - val_loss: 2.2288
# Epoch 98/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5641 - val_loss: 2.2258
# Epoch 99/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.5633 - val_loss: 2.2228
# Epoch 100/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5717 - val_loss: 2.2198
# Epoch 101/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5576 - val_loss: 2.2168
# Epoch 102/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5655 - val_loss: 2.2139
# Epoch 103/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5616 - val_loss: 2.2109
# Epoch 104/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5495 - val_loss: 2.2079
# Epoch 105/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.5565 - val_loss: 2.2049
# Epoch 106/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5569 - val_loss: 2.2019
# Epoch 107/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5516 - val_loss: 2.1989
# Epoch 108/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5546 - val_loss: 2.1960
# Epoch 109/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5545 - val_loss: 2.1930
# Epoch 110/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5408 - val_loss: 2.1900
# Epoch 111/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5442 - val_loss: 2.1870
# Epoch 112/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5406 - val_loss: 2.1840
# Epoch 113/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.5435 - val_loss: 2.1810
# Epoch 114/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5369 - val_loss: 2.1780
# Epoch 115/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5389 - val_loss: 2.1751
# Epoch 116/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.5298 - val_loss: 2.1721
# Epoch 117/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5412 - val_loss: 2.1691
# Epoch 118/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5294 - val_loss: 2.1661
# Epoch 119/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5252 - val_loss: 2.1631
# Epoch 120/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5233 - val_loss: 2.1601
# Epoch 121/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5194 - val_loss: 2.1571
# Epoch 122/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5230 - val_loss: 2.1542
# Epoch 123/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.5216 - val_loss: 2.1512
# Epoch 124/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5210 - val_loss: 2.1482
# Epoch 125/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5148 - val_loss: 2.1452
# Epoch 126/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5140 - val_loss: 2.1422
# Epoch 127/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5074 - val_loss: 2.1392
# Epoch 128/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5051 - val_loss: 2.1362
# Epoch 129/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5105 - val_loss: 2.1333
# Epoch 130/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5070 - val_loss: 2.1303
# Epoch 131/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.5028 - val_loss: 2.1273
# Epoch 132/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.5082 - val_loss: 2.1243
# Epoch 133/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4957 - val_loss: 2.1213
# Epoch 134/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4960 - val_loss: 2.1183
# Epoch 135/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4979 - val_loss: 2.1153
# Epoch 136/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4978 - val_loss: 2.1123
# Epoch 137/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4972 - val_loss: 2.1093
# Epoch 138/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4930 - val_loss: 2.1064
# Epoch 139/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4908 - val_loss: 2.1034
# Epoch 140/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4916 - val_loss: 2.1004
# Epoch 141/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4915 - val_loss: 2.0974
# Epoch 142/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4780 - val_loss: 2.0945
# Epoch 143/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4750 - val_loss: 2.0915
# Epoch 144/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4819 - val_loss: 2.0885
# Epoch 145/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4773 - val_loss: 2.0855
# Epoch 146/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4667 - val_loss: 2.0826
# Epoch 147/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4709 - val_loss: 2.0796
# Epoch 148/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4728 - val_loss: 2.0766
# Epoch 149/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4741 - val_loss: 2.0737
# Epoch 150/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4644 - val_loss: 2.0707
# Epoch 151/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4653 - val_loss: 2.0677
# Epoch 152/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4643 - val_loss: 2.0647
# Epoch 153/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4544 - val_loss: 2.0618
# Epoch 154/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4662 - val_loss: 2.0588
# Epoch 155/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4567 - val_loss: 2.0558
# Epoch 156/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4577 - val_loss: 2.0529
# Epoch 157/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4550 - val_loss: 2.0499
# Epoch 158/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4526 - val_loss: 2.0469
# Epoch 159/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4474 - val_loss: 2.0440
# Epoch 160/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 1.4515 - val_loss: 2.0410
# Epoch 161/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4422 - val_loss: 2.0380
# Epoch 162/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4498 - val_loss: 2.0351
# Epoch 163/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4384 - val_loss: 2.0321
# Epoch 164/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4390 - val_loss: 2.0291
# Epoch 165/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4437 - val_loss: 2.0262
# Epoch 166/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4379 - val_loss: 2.0232
# Epoch 167/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.4357 - val_loss: 2.0202
# Epoch 168/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4303 - val_loss: 2.0173
# Epoch 169/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4316 - val_loss: 2.0143
# Epoch 170/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4283 - val_loss: 2.0114
# Epoch 171/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4271 - val_loss: 2.0084
# Epoch 172/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4276 - val_loss: 2.0054
# Epoch 173/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4246 - val_loss: 2.0025
# Epoch 174/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4212 - val_loss: 1.9995
# Epoch 175/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4154 - val_loss: 1.9965
# Epoch 176/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4222 - val_loss: 1.9936
# Epoch 177/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.4055 - val_loss: 1.9906
# Epoch 178/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4108 - val_loss: 1.9877
# Epoch 179/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4045 - val_loss: 1.9847
# Epoch 180/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4097 - val_loss: 1.9817
# Epoch 181/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.4074 - val_loss: 1.9788
# Epoch 182/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.4137 - val_loss: 1.9758
# Epoch 183/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.3978 - val_loss: 1.9729
# Epoch 184/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4033 - val_loss: 1.9699
# Epoch 185/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.4048 - val_loss: 1.9669
# Epoch 186/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3941 - val_loss: 1.9640
# Epoch 187/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.4004 - val_loss: 1.9610
# Epoch 188/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3962 - val_loss: 1.9581
# Epoch 189/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3880 - val_loss: 1.9551
# Epoch 190/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3917 - val_loss: 1.9522
# Epoch 191/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3875 - val_loss: 1.9492
# Epoch 192/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3861 - val_loss: 1.9462
# Epoch 193/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3813 - val_loss: 1.9433
# Epoch 194/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3821 - val_loss: 1.9403
# Epoch 195/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3719 - val_loss: 1.9373
# Epoch 196/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3702 - val_loss: 1.9344
# Epoch 197/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3747 - val_loss: 1.9314
# Epoch 198/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.3706 - val_loss: 1.9285
# Epoch 199/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3714 - val_loss: 1.9255
# Epoch 200/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3726 - val_loss: 1.9225
# Epoch 201/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3610 - val_loss: 1.9196
# Epoch 202/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3717 - val_loss: 1.9166
# Epoch 203/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.3542 - val_loss: 1.9136
# Epoch 204/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3643 - val_loss: 1.9107
# Epoch 205/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3619 - val_loss: 1.9077
# Epoch 206/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3527 - val_loss: 1.9048
# Epoch 207/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.3496 - val_loss: 1.9018
# Epoch 208/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3538 - val_loss: 1.8988
# Epoch 209/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3508 - val_loss: 1.8959
# Epoch 210/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3525 - val_loss: 1.8929
# Epoch 211/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3450 - val_loss: 1.8899
# Epoch 212/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3478 - val_loss: 1.8870
# Epoch 213/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.3424 - val_loss: 1.8840
# Epoch 214/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3383 - val_loss: 1.8810
# Epoch 215/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3321 - val_loss: 1.8780
# Epoch 216/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.3417 - val_loss: 1.8751
# Epoch 217/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.3297 - val_loss: 1.8721
# Epoch 218/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3327 - val_loss: 1.8691
# Epoch 219/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3343 - val_loss: 1.8662
# Epoch 220/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3322 - val_loss: 1.8632
# Epoch 221/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.3271 - val_loss: 1.8603
# Epoch 222/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3282 - val_loss: 1.8573
# Epoch 223/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3188 - val_loss: 1.8543
# Epoch 224/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 1.3209 - val_loss: 1.8514
# Epoch 225/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3172 - val_loss: 1.8484
# Epoch 226/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3188 - val_loss: 1.8454
# Epoch 227/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.3179 - val_loss: 1.8425
# Epoch 228/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.3106 - val_loss: 1.8395
# Epoch 229/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3118 - val_loss: 1.8366
# Epoch 230/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3092 - val_loss: 1.8336
# Epoch 231/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.3064 - val_loss: 1.8306
# Epoch 232/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.3050 - val_loss: 1.8277
# Epoch 233/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.3004 - val_loss: 1.8247
# Epoch 234/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 1.2992 - val_loss: 1.8218
# Epoch 235/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2978 - val_loss: 1.8188
# Epoch 236/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2978 - val_loss: 1.8158
# Epoch 237/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2938 - val_loss: 1.8129
# Epoch 238/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2938 - val_loss: 1.8099
# Epoch 239/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2881 - val_loss: 1.8070
# Epoch 240/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2854 - val_loss: 1.8040
# Epoch 241/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2803 - val_loss: 1.8011
# Epoch 242/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.2814 - val_loss: 1.7981
# Epoch 243/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2786 - val_loss: 1.7952
# Epoch 244/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2763 - val_loss: 1.7922
# Epoch 245/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2763 - val_loss: 1.7892
# Epoch 246/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2785 - val_loss: 1.7863
# Epoch 247/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2733 - val_loss: 1.7833
# Epoch 248/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2739 - val_loss: 1.7804
# Epoch 249/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2754 - val_loss: 1.7774
# Epoch 250/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2634 - val_loss: 1.7745
# Epoch 251/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2657 - val_loss: 1.7715
# Epoch 252/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2625 - val_loss: 1.7686
# Epoch 253/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.2576 - val_loss: 1.7656
# Epoch 254/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2629 - val_loss: 1.7627
# Epoch 255/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2566 - val_loss: 1.7597
# Epoch 256/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2506 - val_loss: 1.7568
# Epoch 257/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2498 - val_loss: 1.7538
# Epoch 258/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.2529 - val_loss: 1.7509
# Epoch 259/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2480 - val_loss: 1.7480
# Epoch 260/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 1.2554 - val_loss: 1.7450
# Epoch 261/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2470 - val_loss: 1.7421
# Epoch 262/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.2423 - val_loss: 1.7391
# Epoch 263/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 1.2383 - val_loss: 1.7362
# Epoch 264/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2372 - val_loss: 1.7332
# Epoch 265/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2393 - val_loss: 1.7303
# Epoch 266/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2295 - val_loss: 1.7274
# Epoch 267/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2327 - val_loss: 1.7244
# Epoch 268/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2341 - val_loss: 1.7215
# Epoch 269/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.2312 - val_loss: 1.7185
# Epoch 270/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2266 - val_loss: 1.7156
# Epoch 271/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.2240 - val_loss: 1.7126
# Epoch 272/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2263 - val_loss: 1.7097
# Epoch 273/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2216 - val_loss: 1.7068
# Epoch 274/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2137 - val_loss: 1.7038
# Epoch 275/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2241 - val_loss: 1.7009
# Epoch 276/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2170 - val_loss: 1.6980
# Epoch 277/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2184 - val_loss: 1.6950
# Epoch 278/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2121 - val_loss: 1.6921
# Epoch 279/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2101 - val_loss: 1.6892
# Epoch 280/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1.2052 - val_loss: 1.6862
# Epoch 281/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2018 - val_loss: 1.6833
# Epoch 282/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2068 - val_loss: 1.6803
# Epoch 283/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2052 - val_loss: 1.6774
# Epoch 284/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.2042 - val_loss: 1.6745
# Epoch 285/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1913 - val_loss: 1.6715
# Epoch 286/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1943 - val_loss: 1.6686
# Epoch 287/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1944 - val_loss: 1.6657
# Epoch 288/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.1924 - val_loss: 1.6628
# Epoch 289/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1946 - val_loss: 1.6598
# Epoch 290/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1866 - val_loss: 1.6569
# Epoch 291/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1784 - val_loss: 1.6540
# Epoch 292/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1818 - val_loss: 1.6511
# Epoch 293/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1815 - val_loss: 1.6481
# Epoch 294/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1722 - val_loss: 1.6452
# Epoch 295/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1763 - val_loss: 1.6423
# Epoch 296/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1733 - val_loss: 1.6393
# Epoch 297/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1753 - val_loss: 1.6364
# Epoch 298/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1751 - val_loss: 1.6335
# Epoch 299/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.1756 - val_loss: 1.6306
# Epoch 300/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1642 - val_loss: 1.6276
# Epoch 301/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1664 - val_loss: 1.6247
# Epoch 302/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1638 - val_loss: 1.6218
# Epoch 303/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1612 - val_loss: 1.6189
# Epoch 304/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.1541 - val_loss: 1.6160
# Epoch 305/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1538 - val_loss: 1.6130
# Epoch 306/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1561 - val_loss: 1.6101
# Epoch 307/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1508 - val_loss: 1.6072
# Epoch 308/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1501 - val_loss: 1.6043
# Epoch 309/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.1440 - val_loss: 1.6014
# Epoch 310/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1451 - val_loss: 1.5984
# Epoch 311/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1438 - val_loss: 1.5955
# Epoch 312/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1452 - val_loss: 1.5926
# Epoch 313/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1453 - val_loss: 1.5897
# Epoch 314/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1436 - val_loss: 1.5868
# Epoch 315/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1317 - val_loss: 1.5839
# Epoch 316/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1365 - val_loss: 1.5809
# Epoch 317/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1352 - val_loss: 1.5780
# Epoch 318/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1314 - val_loss: 1.5751
# Epoch 319/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1322 - val_loss: 1.5722
# Epoch 320/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1296 - val_loss: 1.5693
# Epoch 321/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1225 - val_loss: 1.5664
# Epoch 322/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1236 - val_loss: 1.5635
# Epoch 323/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1233 - val_loss: 1.5606
# Epoch 324/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1203 - val_loss: 1.5577
# Epoch 325/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1143 - val_loss: 1.5547
# Epoch 326/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1131 - val_loss: 1.5518
# Epoch 327/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1104 - val_loss: 1.5489
# Epoch 328/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1081 - val_loss: 1.5460
# Epoch 329/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1078 - val_loss: 1.5431
# Epoch 330/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1047 - val_loss: 1.5402
# Epoch 331/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1092 - val_loss: 1.5373
# Epoch 332/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1033 - val_loss: 1.5344
# Epoch 333/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.1018 - val_loss: 1.5315
# Epoch 334/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.1022 - val_loss: 1.5286
# Epoch 335/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.1009 - val_loss: 1.5257
# Epoch 336/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0907 - val_loss: 1.5228
# Epoch 337/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0889 - val_loss: 1.5199
# Epoch 338/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.0884 - val_loss: 1.5170
# Epoch 339/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0867 - val_loss: 1.5141
# Epoch 340/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0887 - val_loss: 1.5112
# Epoch 341/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0859 - val_loss: 1.5083
# Epoch 342/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0764 - val_loss: 1.5055
# Epoch 343/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0810 - val_loss: 1.5026
# Epoch 344/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0780 - val_loss: 1.4997
# Epoch 345/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0763 - val_loss: 1.4968
# Epoch 346/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0709 - val_loss: 1.4939
# Epoch 347/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0775 - val_loss: 1.4910
# Epoch 348/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0692 - val_loss: 1.4881
# Epoch 349/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0647 - val_loss: 1.4852
# Epoch 350/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0655 - val_loss: 1.4823
# Epoch 351/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0703 - val_loss: 1.4795
# Epoch 352/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0629 - val_loss: 1.4766
# Epoch 353/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0635 - val_loss: 1.4737
# Epoch 354/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0560 - val_loss: 1.4708
# Epoch 355/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0606 - val_loss: 1.4679
# Epoch 356/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0505 - val_loss: 1.4650
# Epoch 357/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0509 - val_loss: 1.4622
# Epoch 358/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0515 - val_loss: 1.4593
# Epoch 359/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0480 - val_loss: 1.4564
# Epoch 360/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0415 - val_loss: 1.4535
# Epoch 361/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0472 - val_loss: 1.4506
# Epoch 362/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0464 - val_loss: 1.4478
# Epoch 363/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0455 - val_loss: 1.4449
# Epoch 364/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0433 - val_loss: 1.4420
# Epoch 365/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0353 - val_loss: 1.4392
# Epoch 366/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0401 - val_loss: 1.4363
# Epoch 367/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0356 - val_loss: 1.4334
# Epoch 368/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0294 - val_loss: 1.4305
# Epoch 369/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0263 - val_loss: 1.4277
# Epoch 370/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0250 - val_loss: 1.4248
# Epoch 371/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0249 - val_loss: 1.4219
# Epoch 372/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0243 - val_loss: 1.4191
# Epoch 373/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0145 - val_loss: 1.4162
# Epoch 374/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0194 - val_loss: 1.4134
# Epoch 375/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 1.0191 - val_loss: 1.4105
# Epoch 376/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0161 - val_loss: 1.4076
# Epoch 377/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0124 - val_loss: 1.4048
# Epoch 378/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0094 - val_loss: 1.4019
# Epoch 379/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0106 - val_loss: 1.3991
# Epoch 380/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 1.0130 - val_loss: 1.3962
# Epoch 381/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0051 - val_loss: 1.3933
# Epoch 382/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0021 - val_loss: 1.3905
# Epoch 383/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.0035 - val_loss: 1.3876
# Epoch 384/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9946 - val_loss: 1.3848
# Epoch 385/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9988 - val_loss: 1.3819
# Epoch 386/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9913 - val_loss: 1.3791
# Epoch 387/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9957 - val_loss: 1.3762
# Epoch 388/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9943 - val_loss: 1.3734
# Epoch 389/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9848 - val_loss: 1.3705
# Epoch 390/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9864 - val_loss: 1.3677
# Epoch 391/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9882 - val_loss: 1.3648
# Epoch 392/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9845 - val_loss: 1.3620
# Epoch 393/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9872 - val_loss: 1.3591
# Epoch 394/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9815 - val_loss: 1.3563
# Epoch 395/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9798 - val_loss: 1.3534
# Epoch 396/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9789 - val_loss: 1.3506
# Epoch 397/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9754 - val_loss: 1.3478
# Epoch 398/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9733 - val_loss: 1.3449
# Epoch 399/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9747 - val_loss: 1.3421
# Epoch 400/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9710 - val_loss: 1.3392
# Epoch 401/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9659 - val_loss: 1.3364
# Epoch 402/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9654 - val_loss: 1.3336
# Epoch 403/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9628 - val_loss: 1.3307
# Epoch 404/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9601 - val_loss: 1.3279
# Epoch 405/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9511 - val_loss: 1.3251
# Epoch 406/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9590 - val_loss: 1.3222
# Epoch 407/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9531 - val_loss: 1.3194
# Epoch 408/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9557 - val_loss: 1.3166
# Epoch 409/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9493 - val_loss: 1.3137
# Epoch 410/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9481 - val_loss: 1.3109
# Epoch 411/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9438 - val_loss: 1.3081
# Epoch 412/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9434 - val_loss: 1.3053
# Epoch 413/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9429 - val_loss: 1.3024
# Epoch 414/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9330 - val_loss: 1.2996
# Epoch 415/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9418 - val_loss: 1.2968
# Epoch 416/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9396 - val_loss: 1.2940
# Epoch 417/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9339 - val_loss: 1.2911
# Epoch 418/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9387 - val_loss: 1.2883
# Epoch 419/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.9316 - val_loss: 1.2855
# Epoch 420/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9276 - val_loss: 1.2827
# Epoch 421/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9289 - val_loss: 1.2799
# Epoch 422/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9284 - val_loss: 1.2771
# Epoch 423/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9208 - val_loss: 1.2742
# Epoch 424/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9213 - val_loss: 1.2714
# Epoch 425/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9178 - val_loss: 1.2686
# Epoch 426/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9204 - val_loss: 1.2658
# Epoch 427/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9167 - val_loss: 1.2630
# Epoch 428/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9103 - val_loss: 1.2602
# Epoch 429/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.9137 - val_loss: 1.2574
# Epoch 430/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9072 - val_loss: 1.2546
# Epoch 431/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.9081 - val_loss: 1.2518
# Epoch 432/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9047 - val_loss: 1.2490
# Epoch 433/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.9011 - val_loss: 1.2462
# Epoch 434/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8989 - val_loss: 1.2434
# Epoch 435/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8961 - val_loss: 1.2406
# Epoch 436/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8910 - val_loss: 1.2377
# Epoch 437/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8946 - val_loss: 1.2349
# Epoch 438/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8909 - val_loss: 1.2321
# Epoch 439/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8936 - val_loss: 1.2293
# Epoch 440/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8946 - val_loss: 1.2265
# Epoch 441/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8850 - val_loss: 1.2238
# Epoch 442/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8905 - val_loss: 1.2210
# Epoch 443/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8736 - val_loss: 1.2182
# Epoch 444/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8806 - val_loss: 1.2154
# Epoch 445/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8764 - val_loss: 1.2126
# Epoch 446/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8767 - val_loss: 1.2098
# Epoch 447/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8772 - val_loss: 1.2070
# Epoch 448/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8748 - val_loss: 1.2042
# Epoch 449/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8741 - val_loss: 1.2014
# Epoch 450/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8714 - val_loss: 1.1987
# Epoch 451/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8673 - val_loss: 1.1959
# Epoch 452/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8669 - val_loss: 1.1931
# Epoch 453/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8666 - val_loss: 1.1903
# Epoch 454/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8618 - val_loss: 1.1875
# Epoch 455/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8604 - val_loss: 1.1848
# Epoch 456/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8613 - val_loss: 1.1820
# Epoch 457/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8573 - val_loss: 1.1792
# Epoch 458/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8543 - val_loss: 1.1765
# Epoch 459/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8493 - val_loss: 1.1737
# Epoch 460/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8503 - val_loss: 1.1709
# Epoch 461/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8482 - val_loss: 1.1682
# Epoch 462/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.8467 - val_loss: 1.1654
# Epoch 463/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8430 - val_loss: 1.1626
# Epoch 464/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8422 - val_loss: 1.1599
# Epoch 465/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8420 - val_loss: 1.1571
# Epoch 466/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8383 - val_loss: 1.1543
# Epoch 467/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8350 - val_loss: 1.1516
# Epoch 468/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8354 - val_loss: 1.1488
# Epoch 469/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8354 - val_loss: 1.1461
# Epoch 470/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8293 - val_loss: 1.1433
# Epoch 471/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8311 - val_loss: 1.1406
# Epoch 472/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8245 - val_loss: 1.1378
# Epoch 473/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8256 - val_loss: 1.1351
# Epoch 474/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8200 - val_loss: 1.1323
# Epoch 475/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8204 - val_loss: 1.1296
# Epoch 476/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8171 - val_loss: 1.1269
# Epoch 477/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8164 - val_loss: 1.1241
# Epoch 478/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8183 - val_loss: 1.1214
# Epoch 479/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8104 - val_loss: 1.1187
# Epoch 480/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8139 - val_loss: 1.1159
# Epoch 481/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8118 - val_loss: 1.1132
# Epoch 482/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8047 - val_loss: 1.1105
# Epoch 483/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8055 - val_loss: 1.1077
# Epoch 484/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8064 - val_loss: 1.1050
# Epoch 485/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8019 - val_loss: 1.1023
# Epoch 486/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8016 - val_loss: 1.0995
# Epoch 487/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7950 - val_loss: 1.0968
# Epoch 488/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.8019 - val_loss: 1.0941
# Epoch 489/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7900 - val_loss: 1.0914
# Epoch 490/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.7941 - val_loss: 1.0887
# Epoch 491/1000
# ...
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2414 - val_loss: 0.3113
# Epoch 827/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2375 - val_loss: 0.3095
# Epoch 828/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2349 - val_loss: 0.3078
# Epoch 829/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2350 - val_loss: 0.3060
# Epoch 830/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2344 - val_loss: 0.3043
# Epoch 831/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2332 - val_loss: 0.3025
# Epoch 832/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2325 - val_loss: 0.3008
# Epoch 833/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2304 - val_loss: 0.2990
# Epoch 834/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2259 - val_loss: 0.2973
# Epoch 835/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2282 - val_loss: 0.2955
# Epoch 836/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2263 - val_loss: 0.2938
# Epoch 837/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2261 - val_loss: 0.2921
# Epoch 838/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2267 - val_loss: 0.2904
# Epoch 839/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2240 - val_loss: 0.2886
# Epoch 840/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2195 - val_loss: 0.2869
# Epoch 841/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2228 - val_loss: 0.2852
# Epoch 842/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2223 - val_loss: 0.2835
# Epoch 843/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2183 - val_loss: 0.2818
# Epoch 844/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2157 - val_loss: 0.2801
# Epoch 845/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2159 - val_loss: 0.2784
# Epoch 846/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2137 - val_loss: 0.2767
# Epoch 847/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2127 - val_loss: 0.2750
# Epoch 848/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2122 - val_loss: 0.2734
# Epoch 849/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2124 - val_loss: 0.2717
# Epoch 850/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2103 - val_loss: 0.2700
# Epoch 851/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2083 - val_loss: 0.2683
# Epoch 852/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2100 - val_loss: 0.2667
# Epoch 853/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2074 - val_loss: 0.2650
# Epoch 854/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2075 - val_loss: 0.2634
# Epoch 855/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2025 - val_loss: 0.2617
# Epoch 856/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2031 - val_loss: 0.2601
# Epoch 857/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2025 - val_loss: 0.2585
# Epoch 858/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2007 - val_loss: 0.2568
# Epoch 859/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2006 - val_loss: 0.2552
# Epoch 860/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1975 - val_loss: 0.2536
# Epoch 861/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1968 - val_loss: 0.2520
# Epoch 862/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1969 - val_loss: 0.2503
# Epoch 863/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1975 - val_loss: 0.2487
# Epoch 864/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1944 - val_loss: 0.2471
# Epoch 865/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1937 - val_loss: 0.2455
# Epoch 866/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1903 - val_loss: 0.2439
# Epoch 867/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1919 - val_loss: 0.2423
# Epoch 868/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1897 - val_loss: 0.2407
# Epoch 869/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1885 - val_loss: 0.2392
# Epoch 870/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1877 - val_loss: 0.2376
# Epoch 871/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1860 - val_loss: 0.2360
# Epoch 872/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1813 - val_loss: 0.2344
# Epoch 873/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1815 - val_loss: 0.2329
# Epoch 874/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1835 - val_loss: 0.2313
# Epoch 875/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1824 - val_loss: 0.2298
# Epoch 876/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1797 - val_loss: 0.2282
# Epoch 877/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1805 - val_loss: 0.2267
# Epoch 878/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1794 - val_loss: 0.2251
# Epoch 879/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1759 - val_loss: 0.2236
# Epoch 880/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1765 - val_loss: 0.2220
# Epoch 881/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1725 - val_loss: 0.2205
# Epoch 882/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1751 - val_loss: 0.2190
# Epoch 883/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1722 - val_loss: 0.2175
# Epoch 884/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.1709 - val_loss: 0.2160
# Epoch 885/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1717 - val_loss: 0.2145
# Epoch 886/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1685 - val_loss: 0.2129
# Epoch 887/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1665 - val_loss: 0.2115
# Epoch 888/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1658 - val_loss: 0.2100
# Epoch 889/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1656 - val_loss: 0.2085
# Epoch 890/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1644 - val_loss: 0.2070
# Epoch 891/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1644 - val_loss: 0.2055
# Epoch 892/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1619 - val_loss: 0.2040
# Epoch 893/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1632 - val_loss: 0.2026
# Epoch 894/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1593 - val_loss: 0.2011
# Epoch 895/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1584 - val_loss: 0.1996
# Epoch 896/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1585 - val_loss: 0.1982
# Epoch 897/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1572 - val_loss: 0.1967
# Epoch 898/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1561 - val_loss: 0.1953
# Epoch 899/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1575 - val_loss: 0.1938
# Epoch 900/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1548 - val_loss: 0.1924
# Epoch 901/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1531 - val_loss: 0.1910
# Epoch 902/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1512 - val_loss: 0.1895
# Epoch 903/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1500 - val_loss: 0.1881
# Epoch 904/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1511 - val_loss: 0.1867
# Epoch 905/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1477 - val_loss: 0.1853
# Epoch 906/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1493 - val_loss: 0.1839
# Epoch 907/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1464 - val_loss: 0.1825
# Epoch 908/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1453 - val_loss: 0.1811
# Epoch 909/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1452 - val_loss: 0.1797
# Epoch 910/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1447 - val_loss: 0.1783
# Epoch 911/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1439 - val_loss: 0.1769
# Epoch 912/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1420 - val_loss: 0.1755
# Epoch 913/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1415 - val_loss: 0.1742
# Epoch 914/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1404 - val_loss: 0.1728
# Epoch 915/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1402 - val_loss: 0.1714
# Epoch 916/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1369 - val_loss: 0.1701
# Epoch 917/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1360 - val_loss: 0.1687
# Epoch 918/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1355 - val_loss: 0.1674
# Epoch 919/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1354 - val_loss: 0.1660
# Epoch 920/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1343 - val_loss: 0.1647
# Epoch 921/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1308 - val_loss: 0.1634
# Epoch 922/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1328 - val_loss: 0.1620
# Epoch 923/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1318 - val_loss: 0.1607
# Epoch 924/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1326 - val_loss: 0.1594
# Epoch 925/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1306 - val_loss: 0.1581
# Epoch 926/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1289 - val_loss: 0.1568
# Epoch 927/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1283 - val_loss: 0.1555
# Epoch 928/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1282 - val_loss: 0.1542
# Epoch 929/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1262 - val_loss: 0.1529
# Epoch 930/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1246 - val_loss: 0.1516
# Epoch 931/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1248 - val_loss: 0.1503
# Epoch 932/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1221 - val_loss: 0.1491
# Epoch 933/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1218 - val_loss: 0.1478
# Epoch 934/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1223 - val_loss: 0.1465
# Epoch 935/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1204 - val_loss: 0.1453
# Epoch 936/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1194 - val_loss: 0.1440
# Epoch 937/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1188 - val_loss: 0.1427
# Epoch 938/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1183 - val_loss: 0.1415
# Epoch 939/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1158 - val_loss: 0.1403
# Epoch 940/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1147 - val_loss: 0.1390
# Epoch 941/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1150 - val_loss: 0.1378
# Epoch 942/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1124 - val_loss: 0.1366
# Epoch 943/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1137 - val_loss: 0.1353
# Epoch 944/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1107 - val_loss: 0.1341
# Epoch 945/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1120 - val_loss: 0.1329
# Epoch 946/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1109 - val_loss: 0.1317
# Epoch 947/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1103 - val_loss: 0.1305
# Epoch 948/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1088 - val_loss: 0.1293
# Epoch 949/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1098 - val_loss: 0.1282
# Epoch 950/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1071 - val_loss: 0.1270
# Epoch 951/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1081 - val_loss: 0.1258
# Epoch 952/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1057 - val_loss: 0.1246
# Epoch 953/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1055 - val_loss: 0.1235
# Epoch 954/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1033 - val_loss: 0.1223
# Epoch 955/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1029 - val_loss: 0.1211
# Epoch 956/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1028 - val_loss: 0.1200
# Epoch 957/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1013 - val_loss: 0.1189
# Epoch 958/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1001 - val_loss: 0.1177
# Epoch 959/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0987 - val_loss: 0.1166
# Epoch 960/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1001 - val_loss: 0.1155
# Epoch 961/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0969 - val_loss: 0.1143
# Epoch 962/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0981 - val_loss: 0.1132
# Epoch 963/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0975 - val_loss: 0.1121
# Epoch 964/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0954 - val_loss: 0.1110
# Epoch 965/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0945 - val_loss: 0.1099
# Epoch 966/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0922 - val_loss: 0.1088
# Epoch 967/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0933 - val_loss: 0.1077
# Epoch 968/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0932 - val_loss: 0.1066
# Epoch 969/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0902 - val_loss: 0.1055
# Epoch 970/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0933 - val_loss: 0.1045
# Epoch 971/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0911 - val_loss: 0.1034
# Epoch 972/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0888 - val_loss: 0.1023
# Epoch 973/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0908 - val_loss: 0.1013
# Epoch 974/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0876 - val_loss: 0.1002
# Epoch 975/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0858 - val_loss: 0.0992
# Epoch 976/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0869 - val_loss: 0.0981
# Epoch 977/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0862 - val_loss: 0.0971
# Epoch 978/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0844 - val_loss: 0.0961
# Epoch 979/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0858 - val_loss: 0.0950
# Epoch 980/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0824 - val_loss: 0.0940
# Epoch 981/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0837 - val_loss: 0.0930
# Epoch 982/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0825 - val_loss: 0.0920
# Epoch 983/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0810 - val_loss: 0.0910
# Epoch 984/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0803 - val_loss: 0.0900
# Epoch 985/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0797 - val_loss: 0.0890
# Epoch 986/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0790 - val_loss: 0.0881
# Epoch 987/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0780 - val_loss: 0.0871
# Epoch 988/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0771 - val_loss: 0.0861
# Epoch 989/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0770 - val_loss: 0.0852
# Epoch 990/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0771 - val_loss: 0.0842
# Epoch 991/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0759 - val_loss: 0.0832
# Epoch 992/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0744 - val_loss: 0.0823
# Epoch 993/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0752 - val_loss: 0.0814
# Epoch 994/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0731 - val_loss: 0.0804
# Epoch 995/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0729 - val_loss: 0.0795
# Epoch 996/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0727 - val_loss: 0.0786
# Epoch 997/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0726 - val_loss: 0.0776
# Epoch 998/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0717 - val_loss: 0.0767
# Epoch 999/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0699 - val_loss: 0.0758
# Epoch 1000/1000
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0679 - val_loss: 0.0749
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3226
# 0.4113742411136627

# %% [markdown]
# Finally, we evaluate the model with RMSE.

# %%
name = 'TNN_3.keras'
model.save(name , overwrite=True)

# %%
from sklearn import metrics

#score_x = np.sqrt(metrics.mean_squared_error(pred[:,0],y_test[:,0]))
#print("X Score (RMSE): {}".format(score_x))

#score_u = np.sqrt(metrics.mean_squared_error(pred[:,1],y_test[:,1]))
#print("U Score (RMSE): {}".format(score_u))

# %%
preds_x = []
rmse_x = []
preds_u = []
rmse_u = []


for x,y in [[x_test1, y_test1],[x_test2, y_test2],[x_test3, y_test3]]:
    pred = model.predict(x)

    score_x = np.sqrt(metrics.mean_squared_error(pred[:,0],y[:,0]))
    print("X Score (RMSE): {}".format(score_x))
    preds_x.append(pred[:,0])
    rmse_x.append(score_x)
    try:
        score_u = np.sqrt(metrics.mean_squared_error(pred[:,1],y[:,1]))
        print("U Score (RMSE): {}".format(score_u))
        preds_u.append(pred[:,1])
        rmse_u.append(score_u)
    except:
        continue

print('Prediction shape: ', len(preds_x))
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# X Score (RMSE): 0.5958671690435732
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# X Score (RMSE): 0.5557979839251608
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# X Score (RMSE): 0.7561145644590624
# Prediction shape:  3

# %%
import csv
# New filename for clarity
new_filename = "TNN_.csv"

# Create and write to the new CSV file with model parameters and results
with open(new_filename, 'a', newline='') as file:
    writer = csv.writer(file)
    # Writing headers for model parameters
    headers = list(model_params.keys())
    headers.append('rmse_x_1')
    headers.append('rmse_x_2')
    headers.append('rmse_x_3')
    headers.append(name)
    writer.writerow(headers)
    
    # Writing values
    values = list(model_params.values())
    values.append(rmse_x[0])  # Adding first RMSE
    values.append(rmse_x[1])  # Adding second RMSE
    values.append(rmse_x[2])  
    # values.append(rmse_u[0])  # Adding first RMSE
    # values.append(rmse_u[1])  # Adding second RMSE
    # values.append(rmse_u[2])
    values.append('')
    writer.writerow(values)

# %%
import matplotlib.pyplot as plt
func = 0
plt.figure(figsize=(6, 4))
plt.plot(y_test1[:,0], 's-',color='C1', label=f'x actual {func+1}')
plt.plot(preds_x[func], '-',color='C2', label=f'x pred {func+1}')

try:
    plt.plot(y_test1[:,1], 's-',color='C0', label=f'u actual {func+1}')
    plt.plot(preds_u[func], '-',color='C3', label=f'u pred {func+1}')
except:
    pass
plt.legend()

# %%
import matplotlib.pyplot as plt
func = 1
plt.figure(figsize=(6, 4))
plt.plot(y_test2[:,0], 's-',color='C1', label=f'x actual {func+1}')
plt.plot(preds_x[func], '-',color='C2', label=f'x pred {func+1}')

try:
    plt.plot(y_test2[:,1], 's-',color='C0', label=f'u actual {func+1}')
    plt.plot(preds_u[func], '-',color='C3', label=f'u pred {func+1}')
except:
    pass
plt.legend()

# %%
import matplotlib.pyplot as plt
func = 2
plt.figure(figsize=(6, 4))
plt.plot(y_test3[:,0], 's-',color='C1', label=f'x actual {func+1}')
plt.plot(preds_x[func], '-',color='C2', label=f'x pred {func+1}')

try:
    plt.plot(y_test3[:,1], 's-',color='C0', label=f'u actual {func+1}')
    plt.plot(preds_u[func], '-',color='C3', label=f'u pred {func+1}')
except:
    pass
plt.legend()
